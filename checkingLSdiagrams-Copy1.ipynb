# %%
import subprocess
import os
import matplotlib.pyplot as plt
from gatspy import periodic
import numpy as np

# %%
dirlist = os.listdir('./me')

# %%
misclist = [x for x in dirlist if 'misc' in x]

# %%
import temporaryFile

# %%
colours = {'u':'blue','g':'green','r':'red','i':'orange','z':'yellow','y':'black'}

# %%
periodlist = np.logspace(-2.5,1.4)
numsteps = 1000000
fmin = periodlist[0]
df = (periodlist[-1]-periodlist[0])/numsteps

for x in range(len(misclist)):
    
    finder1 = '_'
    finder2 = '.'
    loc1 = misclist[x].find(finder1)
    loc2 = misclist[x].find(finder2)
    number = misclist[x][loc1+1:loc2]
    try:
        number = int(number)
    except ValueError:
        print(number)
    os.chdir('/home/mj1e16/iridisRepo/me')
    f = open(misclist[x],'r')
    filestring = f.read()
    f.close()
    filestring = filestring.replace(" ",",")
    filestring = filestring.replace(",,,",",")
    filestring = filestring.replace(",,",",")
    filestring = filestring.replace(",=,","=")
    filestring = filestring.replace("[,","[")
    filestring = filestring.replace(",,",",")
    filestring = filestring.replace(",\n",",")
    filestring = filestring.replace("sampledLC","#sampledLC")
    filestring = filestring.replace("\maxpowers","#\maxpowers")
    f = open('temporaryFile.py','w')
    f.write(filestring)
    f.close()
    reload(temporaryFile)
    date = temporaryFile.date
    mag = temporaryFile.mag
    error = temporaryFile.error
    filters = temporaryFile.filts
    if len(date) != 0:
        freqs = fmin + df * np.arange(numsteps) 
        model = periodic.LombScargleMultibandFast(fit_period=False)
        model.fit(date, mag, error, filters)
        power = model.score_frequency_grid(fmin, df, numsteps) 
        model.optimizer.period_range=(0.003, 26)
        LSperiod = model.best_period
        fig, ax = plt.subplots()
        ax.plot(np.log10(freqs), np.log10(power))
        ax.set(xlabel='period (days)',
               ylabel='Lomb-Scargle Power',
              title='Period = '+str(periodlist[number])+', MeasuredPeriod = '+str(LSperiod))
        plt.show()
        for y in range(len(date)):
            plt.plot(date[y],mag[y],'o',color=colours[filters[y]],markersize=1.5)
        plt.show()
    else:
        print(len(date),misclist[x])
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5707476 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro19292_17.txt')
# (0, 'miscastro6300_0.txt')
# (0, 'miscastro33112_17.txt')
# (0, 'miscastro6301_17.txt')
# (0, 'miscastro132217_4.txt')
# (0, 'miscastro33113_0.txt')
# (0, 'miscastro63013_17.txt')
# (0, 'miscastro63019_17.txt')
# (0, 'miscastro63012_15.txt')
# (0, 'miscastro6301_2.txt')
# (0, 'miscastro13047_5.txt')
# (0, 'miscastro13224_2.txt')
# (0, 'miscastro33117_8.txt')
# (0, 'miscastro6303_12.txt')
# (0, 'miscastro13042_18.txt')
# (0, 'miscastro33119_17.txt')
# (0, 'miscastro130411_8.txt')
# (0, 'miscastro13228_1.txt')
# (0, 'miscastro6304_13.txt')
# (0, 'miscastro19299_11.txt')
# (0, 'miscastro331114_18.txt')
# (0, 'miscastro19298_14.txt')
# (0, 'miscastro19292_3.txt')
# (0, 'miscastro130410_17.txt')
# (0, 'miscastro132218_2.txt')
# (0, 'miscastro192919_19.txt')
# (0, 'miscastro13048_2.txt')
# (0, 'miscastro6308_0.txt')
# (0, 'miscastro6302_6.txt')
# (0, 'miscastro132217_7.txt')
# (0, 'miscastro13224_16.txt')
# (0, 'miscastro13225_5.txt')
# (0, 'miscastro132213_12.txt')
# (0, 'miscastro33117_11.txt')
# (0, 'miscastro192912_13.txt')
# (0, 'miscastro13228_10.txt')
# (0, 'miscastro13222_11.txt')
# (0, 'miscastro33117_3.txt')
# (0, 'miscastro13229_15.txt')
# (0, 'miscastro19290_9.txt')
# (0, 'miscastro33119_10.txt')
# (0, 'miscastro130410_2.txt')
# (0, 'miscastro13043_7.txt')
# (0, 'miscastro132214_6.txt')
# (0, 'miscastro13045_0.txt')
# (0, 'miscastro63011_18.txt')
# (0, 'miscastro130416_14.txt')
# (0, 'miscastro192913_5.txt')
# (0, 'miscastro192913_16.txt')
# (0, 'miscastro13223_0.txt')
# (0, 'miscastro192918_11.txt')
# (0, 'miscastro19299_13.txt')
# (0, 'miscastro19297_6.txt')
# (0, 'miscastro13228_18.txt')
# (0, 'miscastro33113_5.txt')
# (0, 'miscastro132215_7.txt')
# (0, 'miscastro13044_15.txt')
# (0, 'miscastro33114_17.txt')
# (0, 'miscastro19294_18.txt')
# (0, 'miscastro132217_14.txt')
# (0, 'miscastro13043_14.txt')
# (0, 'miscastro33112_8.txt')
# (0, 'miscastro192910_11.txt')
# (0, 'miscastro13044_12.txt')
# (0, 'miscastro6300_9.txt')
# (0, 'miscastro13041_19.txt')
# (0, 'miscastro130413_5.txt')
# (0, 'miscastro19292_11.txt')
# (0, 'miscastro13224_7.txt')
# (0, 'miscastro13222_7.txt')
# (0, 'miscastro192913_12.txt')
# (0, 'miscastro331117_18.txt')
# (0, 'miscastro331114_11.txt')
# (0, 'miscastro6302_4.txt')
# (0, 'miscastro331115_11.txt')
# (0, 'miscastro19290_0.txt')
# (0, 'miscastro132216_1.txt')
# (0, 'miscastro19291_2.txt')
# (0, 'miscastro6308_6.txt')
# (0, 'miscastro63019_6.txt')
# (0, 'miscastro130412_18.txt')
# (0, 'miscastro19299_19.txt')
# (0, 'miscastro130416_13.txt')
# (0, 'miscastro130414_13.txt')
# (0, 'miscastro192918_18.txt')
# (0, 'miscastro13225_8.txt')
# (0, 'miscastro63012_0.txt')
# (0, 'miscastro130418_15.txt')
# (0, 'miscastro130415_3.txt')
# (0, 'miscastro130415_7.txt')
# (0, 'miscastro331119_12.txt')
# (0, 'miscastro13225_10.txt')
# (0, 'miscastro63015_17.txt')
# (0, 'miscastro13046_14.txt')
# (0, 'miscastro13226_4.txt')
# (0, 'miscastro130411_16.txt')
# (0, 'miscastro19296_12.txt')
# (0, 'miscastro63018_6.txt')
# (0, 'miscastro13220_16.txt')
# (0, 'miscastro13046_17.txt')
# (0, 'miscastro331114_10.txt')
# (0, 'miscastro63019_19.txt')
# (0, 'miscastro192917_6.txt')
# (0, 'miscastro130413_9.txt')
# (0, 'miscastro132216_14.txt')
# (0, 'miscastro19299_3.txt')
# (0, 'miscastro63018_2.txt')
# (0, 'miscastro13047_16.txt')
# (0, 'miscastro63013_0.txt')
# (0, 'miscastro331115_12.txt')
# (0, 'miscastro13043_1.txt')
# (0, 'miscastro33113_17.txt')
# (0, 'miscastro13041_0.txt')
# (0, 'miscastro19292_19.txt')
# (0, 'miscastro6308_12.txt')
# (0, 'miscastro63018_4.txt')
# (0, 'miscastro132216_13.txt')
# (0, 'miscastro13047_8.txt')
# (0, 'miscastro33113_16.txt')
# (0, 'miscastro13040_19.txt')
# (0, 'miscastro132212_0.txt')
# (0, 'miscastro6305_14.txt')
# (0, 'miscastro331115_9.txt')
# (0, 'miscastro19292_18.txt')
# (0, 'miscastro331114_19.txt')
# (0, 'miscastro33110_1.txt')
# (0, 'miscastro331114_7.txt')
# (0, 'miscastro130418_11.txt')
# (0, 'miscastro33115_4.txt')
# (0, 'miscastro6302_16.txt')
# (0, 'miscastro63010_0.txt')
# (0, 'miscastro33114_7.txt')
# (0, 'miscastro130416_17.txt')
# (0, 'miscastro132215_19.txt')
# (0, 'miscastro63014_10.txt')
# (0, 'miscastro6303_7.txt')
# (0, 'miscastro33110_17.txt')
# (0, 'miscastro6307_6.txt')
# (0, 'miscastro132215_0.txt')
# (0, 'miscastro331110_16.txt')
# (0, 'miscastro63017_8.txt')
# (0, 'miscastro13222_16.txt')
# (0, 'miscastro13048_17.txt')
# (0, 'miscastro19292_6.txt')
# (0, 'miscastro6301_3.txt')
# (0, 'miscastro192910_13.txt')
# (0, 'miscastro63018_5.txt')
# (0, 'miscastro331115_13.txt')
# (0, 'miscastro33117_18.txt')
# (0, 'miscastro331119_9.txt')
# (0, 'miscastro33112_14.txt')
# (0, 'miscastro130413_15.txt')
# (0, 'miscastro33113_10.txt')
# (0, 'miscastro6308_3.txt')
# (0, 'miscastro33113_7.txt')
# (0, 'miscastro192911_14.txt')
# (0, 'miscastro331118_6.txt')
# (0, 'miscastro132216_9.txt')
# (0, 'miscastro132216_0.txt')
# (0, 'miscastro130416_9.txt')
# (0, 'miscastro13044_1.txt')
# (0, 'miscastro19297_8.txt')
# (0, 'miscastro63019_15.txt')
# (0, 'miscastro130414_7.txt')
# (0, 'miscastro19295_18.txt')
# (0, 'miscastro6301_11.txt')
# (0, 'miscastro13224_12.txt')
# (0, 'miscastro331115_2.txt')
# (0, 'miscastro19291_0.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.0636
#  - Using 5 steps per peak; omega_step = 0.0127
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 164544 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0636
#  - Using 5 steps per peak; omega_step = 0.0127
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 164544 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro132215_3.txt')
# (0, 'miscastro13225_18.txt')
# (0, 'miscastro331114_2.txt')
# (0, 'miscastro63016_10.txt')
# (0, 'miscastro63010_6.txt')
# (0, 'miscastro13044_19.txt')
# (0, 'miscastro19297_3.txt')
# (0, 'miscastro33111_1.txt')
# (0, 'miscastro192913_15.txt')
# (0, 'miscastro130412_6.txt')
# (0, 'miscastro331116_13.txt')
# (0, 'miscastro130419_8.txt')
# (0, 'miscastro6304_2.txt')
# (0, 'miscastro6302_1.txt')
# (0, 'miscastro63017_9.txt')
# (0, 'miscastro13224_5.txt')
# (0, 'miscastro331116_19.txt')
# (0, 'miscastro130416_4.txt')
# (0, 'miscastro13046_10.txt')
# (0, 'miscastro192910_2.txt')
# (0, 'miscastro63016_15.txt')
# (0, 'miscastro331115_15.txt')
# (0, 'miscastro6307_12.txt')
# (0, 'miscastro6304_3.txt')
# (0, 'miscastro13224_4.txt')
# (0, 'miscastro192914_5.txt')
# (0, 'miscastro192911_8.txt')
# (0, 'miscastro192914_11.txt')
# (0, 'miscastro13229_14.txt')
# (0, 'miscastro132218_8.txt')
# (0, 'miscastro13221_13.txt')
# (0, 'miscastro130411_10.txt')
# (0, 'miscastro6306_2.txt')
# (0, 'miscastro13222_18.txt')
# (0, 'miscastro19291_16.txt')
# (0, 'miscastro13041_4.txt')
# (0, 'miscastro63017_18.txt')
# (0, 'miscastro331112_0.txt')
# (0, 'miscastro63014_12.txt')
# (0, 'miscastro13229_11.txt')
# (0, 'miscastro6303_5.txt')
# (0, 'miscastro331111_8.txt')
# (0, 'miscastro13047_11.txt')
# (0, 'miscastro331114_5.txt')
# (0, 'miscastro192914_9.txt')
# (0, 'miscastro13226_3.txt')
# (0, 'miscastro19291_12.txt')
# (0, 'miscastro13045_16.txt')
# (0, 'miscastro33113_1.txt')
# (0, 'miscastro13229_0.txt')
# (0, 'miscastro130415_18.txt')
# (0, 'miscastro130417_19.txt')
# (0, 'miscastro19299_6.txt')
# (0, 'miscastro132219_10.txt')
# (0, 'miscastro331117_11.txt')
# (0, 'miscastro6303_10.txt')
# (0, 'miscastro13046_1.txt')
# (0, 'miscastro13040_11.txt')
# (0, 'miscastro6300_11.txt')
# (0, 'miscastro192917_17.txt')
# (0, 'miscastro6303_16.txt')
# (0, 'miscastro13222_0.txt')
# (0, 'miscastro19294_8.txt')
# (0, 'miscastro63018_15.txt')
# (0, 'miscastro33111_15.txt')
# (0, 'miscastro13046_19.txt')
# (0, 'miscastro63015_13.txt')
# (0, 'miscastro6301_16.txt')
# (0, 'miscastro192910_19.txt')
# (0, 'miscastro33111_10.txt')
# (0, 'miscastro132217_16.txt')
# (0, 'miscastro132218_4.txt')
# (0, 'miscastro13048_19.txt')
# (0, 'miscastro331112_11.txt')
# (0, 'miscastro192911_13.txt')
# (0, 'miscastro19296_3.txt')
# (0, 'miscastro13220_0.txt')
# (0, 'miscastro19295_19.txt')
# (0, 'miscastro130414_16.txt')
# (0, 'miscastro63011_11.txt')
# (0, 'miscastro19296_10.txt')
# (0, 'miscastro192912_1.txt')
# (0, 'miscastro19290_4.txt')
# (0, 'miscastro130412_10.txt')
# (0, 'miscastro132213_3.txt')
# (0, 'miscastro33118_9.txt')
# (0, 'miscastro33110_16.txt')
# (0, 'miscastro19292_4.txt')
# (0, 'miscastro19294_13.txt')
# (0, 'miscastro19293_11.txt')
# (0, 'miscastro13228_8.txt')
# (0, 'miscastro6306_16.txt')
# (0, 'miscastro331114_0.txt')
# (0, 'miscastro6307_17.txt')
# (0, 'miscastro192911_18.txt')
# (0, 'miscastro132211_17.txt')
# (0, 'miscastro63015_6.txt')
# (0, 'miscastro13221_1.txt')
# (0, 'miscastro13221_8.txt')
# (0, 'miscastro192912_15.txt')
# (0, 'miscastro33115_6.txt')
# (0, 'miscastro13044_2.txt')
# (0, 'miscastro192917_7.txt')
# (0, 'miscastro6302_2.txt')
# (0, 'miscastro6308_10.txt')
# (0, 'miscastro132213_1.txt')
# (0, 'miscastro33111_4.txt')
# (0, 'miscastro19294_11.txt')
# (0, 'miscastro132212_14.txt')
# (0, 'miscastro33119_3.txt')
# (0, 'miscastro13228_3.txt')
# (0, 'miscastro19293_1.txt')
# (0, 'miscastro6303_3.txt')
# (0, 'miscastro19290_5.txt')
# (0, 'miscastro132214_11.txt')
# (0, 'miscastro130410_19.txt')
# (0, 'miscastro13225_1.txt')
# (0, 'miscastro331118_5.txt')
# (0, 'miscastro33119_4.txt')
# (0, 'miscastro132210_15.txt')
# (0, 'miscastro33115_11.txt')
# (0, 'miscastro132218_11.txt')
# (0, 'miscastro19290_1.txt')
# (0, 'miscastro192917_4.txt')
# (0, 'miscastro33114_12.txt')
# (0, 'miscastro13220_11.txt')
# (0, 'miscastro13228_19.txt')
# (0, 'miscastro132215_6.txt')
# (0, 'miscastro13227_12.txt')
# (0, 'miscastro6308_18.txt')
# (0, 'miscastro33113_14.txt')
# (0, 'miscastro13045_5.txt')
# (0, 'miscastro331112_8.txt')
# (0, 'miscastro13223_2.txt')
# (0, 'miscastro13225_17.txt')
# (0, 'miscastro331112_3.txt')
# (0, 'miscastro13229_16.txt')
# (0, 'miscastro19297_17.txt')
# (0, 'miscastro132216_3.txt')
# (0, 'miscastro331117_17.txt')
# (0, 'miscastro63015_12.txt')
# (0, 'miscastro132213_8.txt')
# (0, 'miscastro331112_12.txt')
# (0, 'miscastro192917_3.txt')
# (0, 'miscastro33116_11.txt')
# (0, 'miscastro192918_9.txt')
# (0, 'miscastro13042_11.txt')
# (0, 'miscastro13220_18.txt')
# (0, 'miscastro19296_0.txt')
# (0, 'miscastro132216_18.txt')
# (0, 'miscastro192915_5.txt')
# (0, 'miscastro130419_4.txt')
# (0, 'miscastro19294_4.txt')
# (0, 'miscastro192914_3.txt')
# (0, 'miscastro13224_14.txt')
# (0, 'miscastro331116_10.txt')
# (0, 'miscastro132218_18.txt')
# (0, 'miscastro33117_2.txt')
# (0, 'miscastro132211_3.txt')
# (0, 'miscastro63017_4.txt')
# (0, 'miscastro130412_15.txt')
# (0, 'miscastro192910_7.txt')
# (0, 'miscastro33115_9.txt')
# (0, 'miscastro63016_2.txt')
# (0, 'miscastro130418_2.txt')
# (0, 'miscastro33118_4.txt')
# (0, 'miscastro19295_6.txt')
# (0, 'miscastro6309_1.txt')
# (0, 'miscastro63015_8.txt')
# (0, 'miscastro13046_5.txt')
# (0, 'miscastro331114_12.txt')
# (0, 'miscastro192918_13.txt')
# (0, 'miscastro63018_12.txt')
# (0, 'miscastro130417_11.txt')
# (0, 'miscastro132214_14.txt')
# (0, 'miscastro6308_5.txt')
# (0, 'miscastro33116_3.txt')
# (0, 'miscastro19294_2.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.0669
#  - Using 5 steps per peak; omega_step = 0.0134
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 156516 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscastro132219_12.txt')
# (0, 'miscastro331118_3.txt')
# (0, 'miscastro132215_13.txt')
# (0, 'miscastro331113_6.txt')
# (0, 'miscastro192915_1.txt')
# (0, 'miscastro130419_17.txt')
# (0, 'miscastro130416_16.txt')
# (0, 'miscastro13046_6.txt')
# (0, 'miscastro132210_0.txt')
# (0, 'miscastro192915_12.txt')
# (0, 'miscastro130414_5.txt')
# (0, 'miscastro13222_1.txt')
# (0, 'miscastro63014_16.txt')
# (0, 'miscastro13041_15.txt')
# (0, 'miscastro192913_17.txt')
# (0, 'miscastro130413_13.txt')
# (0, 'miscastro33115_7.txt')
# (0, 'miscastro63019_7.txt')
# (0, 'miscastro130419_15.txt')
# (0, 'miscastro63011_5.txt')
# (0, 'miscastro192913_3.txt')
# (0, 'miscastro331119_0.txt')
# (0, 'miscastro63012_7.txt')
# (0, 'miscastro13048_14.txt')
# (0, 'miscastro331113_7.txt')
# (0, 'miscastro132219_8.txt')
# (0, 'miscastro6303_4.txt')
# (0, 'miscastro130418_1.txt')
# (0, 'miscastro33111_3.txt')
# (0, 'miscastro192916_6.txt')
# (0, 'miscastro13227_13.txt')
# (0, 'miscastro63012_11.txt')
# (0, 'miscastro13043_2.txt')
# (0, 'miscastro130416_3.txt')
# (0, 'miscastro132211_6.txt')
# (0, 'miscastro132210_2.txt')
# (0, 'miscastro6306_18.txt')
# (0, 'miscastro33118_1.txt')
# (0, 'miscastro63019_4.txt')
# (0, 'miscastro13221_3.txt')
# (0, 'miscastro6306_10.txt')
# (0, 'miscastro132217_5.txt')
# (0, 'miscastro63012_3.txt')
# (0, 'miscastro331118_0.txt')
# (0, 'miscastro132210_1.txt')
# (0, 'miscastro331113_9.txt')
# (0, 'miscastro13042_16.txt')
# (0, 'miscastro63019_0.txt')
# (0, 'miscastro331119_4.txt')
# (0, 'miscastro63016_17.txt')
# (0, 'miscastro132214_0.txt')
# (0, 'miscastro33115_18.txt')
# (0, 'miscastro19290_17.txt')
# (0, 'miscastro33113_18.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5757214 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5707476 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00192
#  - Using 5 steps per peak; omega_step = 0.000383
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5461031 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0669
#  - Using 5 steps per peak; omega_step = 0.0134
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 156516 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5782328 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0669
#  - Using 5 steps per peak; omega_step = 0.0134
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 156516 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5757214 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0577
#  - Using 5 steps per peak; omega_step = 0.0115
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 181415 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5760667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro13229_10.txt')
# (0, 'miscastro331116_15.txt')
# (0, 'miscastro63015_0.txt')
# (0, 'miscastro132219_18.txt')
# (0, 'miscastro331114_6.txt')
# (0, 'miscastro6309_17.txt')
# (0, 'miscastro63013_3.txt')
# (0, 'miscastro132219_9.txt')
# (0, 'miscastro192913_2.txt')
# (0, 'miscastro192910_17.txt')
# (0, 'miscastro33115_17.txt')
# (0, 'miscastro130415_8.txt')
# (0, 'miscastro130414_3.txt')
# (0, 'miscastro130416_19.txt')
# (0, 'miscastro331117_15.txt')
# (0, 'miscastro6307_14.txt')
# (0, 'miscastro192913_19.txt')
# (0, 'miscastro132214_4.txt')
# (0, 'miscastro130411_5.txt')
# (0, 'miscastro192917_8.txt')
# (0, 'miscastro331110_12.txt')
# (0, 'miscastro331111_2.txt')
# (0, 'miscastro19299_7.txt')
# (0, 'miscastro19290_6.txt')
# (0, 'miscastro331119_7.txt')
# (0, 'miscastro33116_19.txt')
# (0, 'miscastro130411_3.txt')
# (0, 'miscastro192911_3.txt')
# (0, 'miscastro331112_15.txt')
# (0, 'miscastro192919_6.txt')
# (0, 'miscastro19296_17.txt')
# (0, 'miscastro13044_18.txt')
# (0, 'miscastro63010_12.txt')
# (0, 'miscastro33117_6.txt')
# (0, 'miscastro33115_0.txt')
# (0, 'miscastro192917_16.txt')
# (0, 'miscastro63010_18.txt')
# (0, 'miscastro63013_6.txt')
# (0, 'miscastro6305_4.txt')
# (0, 'miscastro19298_6.txt')
# (0, 'miscastro331113_19.txt')
# (0, 'miscastro130410_0.txt')
# (0, 'miscastro13229_19.txt')
# (0, 'miscastro13226_5.txt')
# (0, 'miscastro130417_5.txt')
# (0, 'miscastro132214_9.txt')
# (0, 'miscastro6301_10.txt')
# (0, 'miscastro130417_0.txt')
# (0, 'miscastro13049_18.txt')
# (0, 'miscastro6307_4.txt')
# (0, 'miscastro13043_15.txt')
# (0, 'miscastro19291_18.txt')
# (0, 'miscastro132216_7.txt')
# (0, 'miscastro192914_4.txt')
# (0, 'miscastro132210_7.txt')
# (0, 'miscastro63015_2.txt')
# (0, 'miscastro33115_5.txt')
# (0, 'miscastro130417_7.txt')
# (0, 'miscastro130413_10.txt')
# (0, 'miscastro6304_4.txt')
# (0, 'miscastro33119_14.txt')
# (0, 'miscastro132212_11.txt')
# (0, 'miscastro13223_16.txt')
# (0, 'miscastro13048_6.txt')
# (0, 'miscastro192919_1.txt')
# (0, 'miscastro6306_5.txt')
# (0, 'miscastro192914_14.txt')
# (0, 'miscastro6301_19.txt')
# (0, 'miscastro63014_4.txt')
# (0, 'miscastro132214_15.txt')
# (0, 'miscastro331116_11.txt')
# (0, 'miscastro130413_12.txt')
# (0, 'miscastro6303_11.txt')
# (0, 'miscastro33118_15.txt')
# (0, 'miscastro6308_8.txt')
# (0, 'miscastro13048_0.txt')
# (0, 'miscastro192915_13.txt')
# (0, 'miscastro132217_17.txt')
# (0, 'miscastro13226_18.txt')
# (0, 'miscastro33119_11.txt')
# (0, 'miscastro192918_14.txt')
# (0, 'miscastro331112_19.txt')
# (0, 'miscastro331118_4.txt')
# (0, 'miscastro6304_5.txt')
# (0, 'miscastro6304_12.txt')
# (0, 'miscastro63017_5.txt')
# (0, 'miscastro33119_5.txt')
# (0, 'miscastro130419_5.txt')
# (0, 'miscastro130418_10.txt')
# (0, 'miscastro192914_0.txt')
# (0, 'miscastro13221_10.txt')
# (0, 'miscastro13044_13.txt')
# (0, 'miscastro130413_19.txt')
# (0, 'miscastro132211_18.txt')
# (0, 'miscastro130416_5.txt')
# (0, 'miscastro13228_14.txt')
# (0, 'miscastro13043_4.txt')
# (0, 'miscastro13040_5.txt')
# (0, 'miscastro130410_7.txt')
# (0, 'miscastro132212_7.txt')
# (0, 'miscastro13221_19.txt')
# (0, 'miscastro63012_1.txt')
# (0, 'miscastro33112_11.txt')
# (0, 'miscastro6306_13.txt')
# (0, 'miscastro13048_12.txt')
# (0, 'miscastro331119_17.txt')
# (0, 'miscastro130411_18.txt')
# (0, 'miscastro6309_4.txt')
# (0, 'miscastro13221_18.txt')
# (0, 'miscastro33111_6.txt')
# (0, 'miscastro19295_7.txt')
# (0, 'miscastro13042_4.txt')
# (0, 'miscastro19294_14.txt')
# (0, 'miscastro33111_17.txt')
# (0, 'miscastro6306_7.txt')
# (0, 'miscastro63014_8.txt')
# (0, 'miscastro6304_0.txt')
# (0, 'miscastro331115_10.txt')
# (0, 'miscastro13044_11.txt')
# (0, 'miscastro19299_12.txt')
# (0, 'miscastro33113_3.txt')
# (0, 'miscastro33118_18.txt')
# (0, 'miscastro331114_17.txt')
# (0, 'miscastro13040_6.txt')
# (0, 'miscastro13222_3.txt')
# (0, 'miscastro331115_6.txt')
# (0, 'miscastro33115_19.txt')
# (0, 'miscastro33111_0.txt')
# (0, 'miscastro63011_17.txt')
# (0, 'miscastro130417_2.txt')
# (0, 'miscastro6304_15.txt')
# (0, 'miscastro33114_11.txt')
# (0, 'miscastro331118_13.txt')
# (0, 'miscastro33116_17.txt')
# (0, 'miscastro331112_6.txt')
# (0, 'miscastro331117_14.txt')
# (0, 'miscastro6305_2.txt')
# (0, 'miscastro33118_0.txt')
# (0, 'miscastro33110_15.txt')
# (0, 'miscastro19293_14.txt')
# (0, 'miscastro63016_7.txt')
# (0, 'miscastro13046_3.txt')
# (0, 'miscastro33115_3.txt')
# (0, 'miscastro13221_0.txt')
# (0, 'miscastro130419_19.txt')
# (0, 'miscastro132211_10.txt')
# (0, 'miscastro130415_4.txt')
# (0, 'miscastro19297_4.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0669
#  - Using 5 steps per peak; omega_step = 0.0134
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 156516 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0636
#  - Using 5 steps per peak; omega_step = 0.0127
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 164544 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5782328 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0669
#  - Using 5 steps per peak; omega_step = 0.0134
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 156516 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0636
#  - Using 5 steps per peak; omega_step = 0.0127
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 164544 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5753888 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro132210_11.txt')
# (0, 'miscastro6305_0.txt')
# (0, 'miscastro19292_14.txt')
# (0, 'miscastro13040_7.txt')
# (0, 'miscastro132216_8.txt')
# (0, 'miscastro33112_10.txt')
# (0, 'miscastro13226_6.txt')
# (0, 'miscastro132219_19.txt')
# (0, 'miscastro13221_7.txt')
# (0, 'miscastro13043_13.txt')
# (0, 'miscastro19292_7.txt')
# (0, 'miscastro63010_15.txt')
# (0, 'miscastro63018_17.txt')
# (0, 'miscastro13220_3.txt')
# (0, 'miscastro6307_3.txt')
# (0, 'miscastro130419_3.txt')
# (0, 'miscastro331113_14.txt')
# (0, 'miscastro132215_9.txt')
# (0, 'miscastro13045_10.txt')
# (0, 'miscastro33111_2.txt')
# (0, 'miscastro192913_4.txt')
# (0, 'miscastro192910_1.txt')
# (0, 'miscastro13227_8.txt')
# (0, 'miscastro192914_2.txt')
# (0, 'miscastro19293_6.txt')
# (0, 'miscastro19299_15.txt')
# (0, 'miscastro331115_16.txt')
# (0, 'miscastro132218_3.txt')
# (0, 'miscastro33119_18.txt')
# (0, 'miscastro19293_19.txt')
# (0, 'miscastro192918_12.txt')
# (0, 'miscastro33112_7.txt')
# (0, 'miscastro130413_14.txt')
# (0, 'miscastro130415_9.txt')
# (0, 'miscastro13226_11.txt')
# (0, 'miscastro130415_15.txt')
# (0, 'miscastro130410_18.txt')
# (0, 'miscastro331119_8.txt')
# (0, 'miscastro13041_7.txt')
# (0, 'miscastro13221_15.txt')
# (0, 'miscastro19297_0.txt')
# (0, 'miscastro13223_18.txt')
# (0, 'miscastro13227_19.txt')
# (0, 'miscastro33112_15.txt')
# (0, 'miscastro19290_13.txt')
# (0, 'miscastro13224_10.txt')
# (0, 'miscastro192917_2.txt')
# (0, 'miscastro192919_12.txt')
# (0, 'miscastro6302_0.txt')
# (0, 'miscastro19290_11.txt')
# (0, 'miscastro33112_12.txt')
# (0, 'miscastro13221_16.txt')
# (0, 'miscastro63014_2.txt')
# (0, 'miscastro13226_2.txt')
# (0, 'miscastro331111_3.txt')
# (0, 'miscastro13228_5.txt')
# (0, 'miscastro19294_16.txt')
# (0, 'miscastro13220_9.txt')
# (0, 'miscastro33113_8.txt')
# (0, 'miscastro13224_19.txt')
# (0, 'miscastro13044_6.txt')
# (0, 'miscastro6308_14.txt')
# (0, 'miscastro331111_14.txt')
# (0, 'miscastro13226_15.txt')
# (0, 'miscastro130414_8.txt')
# (0, 'miscastro130415_5.txt')
# (0, 'miscastro19298_7.txt')
# (0, 'miscastro19295_15.txt')
# (0, 'miscastro192915_17.txt')
# (0, 'miscastro13220_7.txt')
# (0, 'miscastro192919_11.txt')
# (0, 'miscastro331111_5.txt')
# (0, 'miscastro33117_13.txt')
# (0, 'miscastro33112_16.txt')
# (0, 'miscastro13047_17.txt')
# (0, 'miscastro192918_5.txt')
# (0, 'miscastro6308_15.txt')
# (0, 'miscastro132218_14.txt')
# (0, 'miscastro13044_4.txt')
# (0, 'miscastro192917_0.txt')
# (0, 'miscastro63014_17.txt')
# (0, 'miscastro33111_13.txt')
# (0, 'miscastro6307_16.txt')
# (0, 'miscastro13221_4.txt')
# (0, 'miscastro331116_2.txt')
# (0, 'miscastro331114_3.txt')
# (0, 'miscastro19297_18.txt')
# (0, 'miscastro19298_15.txt')
# (0, 'miscastro6305_19.txt')
# (0, 'miscastro132216_12.txt')
# (0, 'miscastro13045_1.txt')
# (0, 'miscastro19297_1.txt')
# (0, 'miscastro192915_18.txt')
# (0, 'miscastro13221_11.txt')
# (0, 'miscastro130414_14.txt')
# (0, 'miscastro6300_19.txt')
# (0, 'miscastro13042_9.txt')
# (0, 'miscastro33119_15.txt')
# (0, 'miscastro132215_1.txt')
# (0, 'miscastro192915_0.txt')
# (0, 'miscastro33118_17.txt')
# (0, 'miscastro130414_0.txt')
# (0, 'miscastro6301_0.txt')
# (0, 'miscastro6306_4.txt')
# (0, 'miscastro132216_19.txt')
# (0, 'miscastro33117_14.txt')
# (0, 'miscastro6309_18.txt')
# (0, 'miscastro33112_0.txt')
# (0, 'miscastro130417_14.txt')
# (0, 'miscastro19290_3.txt')
# (0, 'miscastro63017_0.txt')
# (0, 'miscastro132212_4.txt')
# (0, 'miscastro13047_12.txt')
# (0, 'miscastro192912_3.txt')
# (0, 'miscastro331111_15.txt')
# (0, 'miscastro130410_3.txt')
# (0, 'miscastro130416_8.txt')
# (0, 'miscastro13225_2.txt')
# (0, 'miscastro13229_3.txt')
# (0, 'miscastro13042_15.txt')
# (0, 'miscastro192915_8.txt')
# (0, 'miscastro130418_12.txt')
# (0, 'miscastro19291_10.txt')
# (0, 'miscastro33117_4.txt')
# (0, 'miscastro13041_3.txt')
# (0, 'miscastro63016_13.txt')
# (0, 'miscastro192919_9.txt')
# (0, 'miscastro13044_10.txt')
# (0, 'miscastro63011_7.txt')
# (0, 'miscastro331111_6.txt')
# (0, 'miscastro13041_10.txt')
# (0, 'miscastro33114_13.txt')
# (0, 'miscastro331113_1.txt')
# (0, 'miscastro192918_0.txt')
# (0, 'miscastro331115_18.txt')
# (0, 'miscastro192917_5.txt')
# (0, 'miscastro63010_17.txt')
# (0, 'miscastro6302_3.txt')
# (0, 'miscastro63015_19.txt')
# (0, 'miscastro13040_17.txt')
# (0, 'miscastro63012_12.txt')
# (0, 'miscastro192913_10.txt')
# (0, 'miscastro63011_15.txt')
# (0, 'miscastro331114_13.txt')
# (0, 'miscastro33112_9.txt')
# (0, 'miscastro132218_5.txt')
# (0, 'miscastro13223_13.txt')
# (0, 'miscastro13223_4.txt')
# (0, 'miscastro6305_15.txt')
# (0, 'miscastro13220_10.txt')
# (0, 'miscastro13046_8.txt')
# (0, 'miscastro132219_4.txt')
# (0, 'miscastro132218_10.txt')
# (0, 'miscastro33114_4.txt')
# (0, 'miscastro130418_8.txt')
# (0, 'miscastro19295_2.txt')
# (0, 'miscastro13048_9.txt')
# (0, 'miscastro132216_17.txt')
# (0, 'miscastro33110_19.txt')
# (0, 'miscastro132215_5.txt')
# (0, 'miscastro19296_16.txt')
# (0, 'miscastro19297_9.txt')
# (0, 'miscastro63016_19.txt')
# (0, 'miscastro13046_4.txt')
# (0, 'miscastro63013_8.txt')
# (0, 'miscastro6308_19.txt')
# (0, 'miscastro192914_18.txt')
# (0, 'miscastro33115_15.txt')
# (0, 'miscastro192919_13.txt')
# (0, 'miscastro192911_4.txt')
# (0, 'miscastro192913_1.txt')
# (0, 'miscastro19297_11.txt')
# (0, 'miscastro132217_12.txt')
# (0, 'miscastro192918_15.txt')
# (0, 'miscastro13045_3.txt')
# (0, 'miscastro130411_14.txt')
# (0, 'miscastro192916_13.txt')
# (0, 'miscastro33113_9.txt')
# (0, 'miscastro132219_5.txt')
# (0, 'miscastro63015_16.txt')
# (0, 'miscastro19295_8.txt')
# (0, 'miscastro6302_14.txt')
# (0, 'miscastro132217_18.txt')
# (0, 'miscastro130413_2.txt')
# (0, 'miscastro130418_7.txt')
# (0, 'miscastro33117_0.txt')
# (0, 'miscastro19293_13.txt')
# (0, 'miscastro6300_10.txt')
# (0, 'miscastro19292_15.txt')
# (0, 'miscastro13227_15.txt')
# (0, 'miscastro63019_16.txt')
# (0, 'miscastro19297_14.txt')
# (0, 'miscastro331113_8.txt')
# (0, 'miscastro132210_6.txt')
# (0, 'miscastro130418_3.txt')
# (0, 'miscastro63010_5.txt')
# (0, 'miscastro33111_12.txt')
# (0, 'miscastro132214_12.txt')
# (0, 'miscastro331116_14.txt')
# (0, 'miscastro13042_7.txt')
# (0, 'miscastro192916_11.txt')
# (0, 'miscastro33119_0.txt')
# (0, 'miscastro6300_17.txt')
# (0, 'miscastro132216_15.txt')
# (0, 'miscastro331118_17.txt')
# (0, 'miscastro6301_8.txt')
# (0, 'miscastro63013_15.txt')
# (0, 'miscastro132211_16.txt')
# (0, 'miscastro63013_14.txt')
# (0, 'miscastro13228_13.txt')
# (0, 'miscastro192910_6.txt')
# (0, 'miscastro130413_17.txt')
# (0, 'miscastro19294_3.txt')
# (0, 'miscastro63017_19.txt')
# (0, 'miscastro33114_9.txt')
# (0, 'miscastro132210_10.txt')
# (0, 'miscastro132218_19.txt')
# (0, 'miscastro13043_12.txt')
# (0, 'miscastro33116_16.txt')
# (0, 'miscastro130418_13.txt')
# (0, 'miscastro130414_2.txt')
# (0, 'miscastro192911_16.txt')
# (0, 'miscastro130418_19.txt')
# (0, 'miscastro63011_16.txt')
# (0, 'miscastro132217_15.txt')
# (0, 'miscastro130418_9.txt')
# (0, 'miscastro6309_0.txt')
# (0, 'miscastro63018_11.txt')
# (0, 'miscastro130415_14.txt')
# (0, 'miscastro13222_19.txt')
# (0, 'miscastro63017_10.txt')
# (0, 'miscastro132217_10.txt')
# (0, 'miscastro13226_17.txt')
# (0, 'miscastro19293_17.txt')
# (0, 'miscastro63010_3.txt')
# (0, 'miscastro19293_18.txt')
# (0, 'miscastro19297_7.txt')
# (0, 'miscastro6300_12.txt')
# (0, 'miscastro13224_8.txt')
# (0, 'miscastro331115_1.txt')
# (0, 'miscastro130417_3.txt')
# (0, 'miscastro63013_1.txt')
# (0, 'miscastro33118_8.txt')
# (0, 'miscastro331110_9.txt')
# (0, 'miscastro63010_10.txt')
# (0, 'miscastro63013_18.txt')
# (0, 'miscastro63014_13.txt')
# (0, 'miscastro331113_15.txt')
# (0, 'miscastro13226_1.txt')
# (0, 'miscastro33110_7.txt')
# (0, 'miscastro132211_2.txt')
# (0, 'miscastro13222_13.txt')
# (0, 'miscastro192917_12.txt')
# (0, 'miscastro19292_9.txt')
# (0, 'miscastro13040_10.txt')
# (0, 'miscastro19291_14.txt')
# (0, 'miscastro19292_13.txt')
# (0, 'miscastro130417_1.txt')
# (0, 'miscastro13227_6.txt')
# (0, 'miscastro192915_15.txt')
# (0, 'miscastro13228_11.txt')
# (0, 'miscastro192911_15.txt')
# (0, 'miscastro33116_10.txt')
# (0, 'miscastro63019_10.txt')
# (0, 'miscastro13049_19.txt')
# (0, 'miscastro130414_9.txt')
# (0, 'miscastro13048_18.txt')
# (0, 'miscastro33114_1.txt')
# (0, 'miscastro130414_4.txt')
# (0, 'miscastro63018_16.txt')
# (0, 'miscastro13047_14.txt')
# (0, 'miscastro192912_11.txt')
# (0, 'miscastro331118_15.txt')
# (0, 'miscastro6307_15.txt')
# (0, 'miscastro13041_13.txt')
# (0, 'miscastro13040_12.txt')
# (0, 'miscastro13225_6.txt')
# (0, 'miscastro331113_3.txt')
# (0, 'miscastro33111_5.txt')
# (0, 'miscastro331111_1.txt')
# (0, 'miscastro192912_0.txt')
# (0, 'miscastro6301_15.txt')
# (0, 'miscastro331115_7.txt')
# (0, 'miscastro13042_3.txt')
# (0, 'miscastro331119_14.txt')
# (0, 'miscastro192914_13.txt')
# (0, 'miscastro192918_2.txt')
# (0, 'miscastro33115_10.txt')
# (0, 'miscastro33114_19.txt')
# (0, 'miscastro13220_5.txt')
# (0, 'miscastro130417_6.txt')
# (0, 'miscastro63018_9.txt')
# (0, 'miscastro130419_7.txt')
# (0, 'miscastro19291_13.txt')
# (0, 'miscastro132215_4.txt')
# (0, 'miscastro6305_12.txt')
# (0, 'miscastro63010_1.txt')
# (0, 'miscastro19297_16.txt')
# (0, 'miscastro63013_19.txt')
# (0, 'miscastro13049_15.txt')
# (0, 'miscastro132215_16.txt')
# (0, 'miscastro6305_6.txt')
# (0, 'miscastro331117_16.txt')
# (0, 'miscastro331114_4.txt')
# (0, 'miscastro192916_18.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5753888 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro132219_0.txt')
# (0, 'miscastro331111_10.txt')
# (0, 'miscastro13226_7.txt')
# (0, 'miscastro192912_4.txt')
# (0, 'miscastro130415_11.txt')
# (0, 'miscastro132218_7.txt')
# (0, 'miscastro331113_11.txt')
# (0, 'miscastro19298_8.txt')
# (0, 'miscastro13220_4.txt')
# (0, 'miscastro132212_5.txt')
# (0, 'miscastro192910_12.txt')
# (0, 'miscastro33117_7.txt')
# (0, 'miscastro6309_3.txt')
# (0, 'miscastro63018_19.txt')
# (0, 'miscastro6305_17.txt')
# (0, 'miscastro192913_6.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5760667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5757214 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro19291_19.txt')
# (0, 'miscastro33116_9.txt')
# (0, 'miscastro6303_17.txt')
# (0, 'miscastro13223_12.txt')
# (0, 'miscastro192919_5.txt')
# (0, 'miscastro130414_17.txt')
# (0, 'miscastro331118_7.txt')
# (0, 'miscastro331119_15.txt')
# (0, 'miscastro132217_2.txt')
# (0, 'miscastro331112_13.txt')
# (0, 'miscastro13048_1.txt')
# (0, 'miscastro19293_2.txt')
# (0, 'miscastro331116_5.txt')
# (0, 'miscastro132211_8.txt')
# (0, 'miscastro130412_0.txt')
# (0, 'miscastro192915_14.txt')
# (0, 'miscastro132211_12.txt')
# (0, 'miscastro331111_17.txt')
# (0, 'miscastro63012_19.txt')
# (0, 'miscastro6302_9.txt')
# (0, 'miscastro331116_8.txt')
# (0, 'miscastro13229_1.txt')
# (0, 'miscastro6307_8.txt')
# (0, 'miscastro192917_15.txt')
# (0, 'miscastro6309_16.txt')
# (0, 'miscastro6302_18.txt')
# (0, 'miscastro63014_18.txt')
# (0, 'miscastro192919_17.txt')
# (0, 'miscastro13220_1.txt')
# (0, 'miscastro130410_11.txt')
# (0, 'miscastro192914_10.txt')
# (0, 'miscastro13041_17.txt')
# (0, 'miscastro331118_19.txt')
# (0, 'miscastro19299_14.txt')
# (0, 'miscastro13049_16.txt')
# (0, 'miscastro13226_14.txt')
# (0, 'miscastro33117_15.txt')
# (0, 'miscastro130415_17.txt')
# (0, 'miscastro19296_4.txt')
# (0, 'miscastro33110_6.txt')
# (0, 'miscastro13044_9.txt')
# (0, 'miscastro19293_3.txt')
# (0, 'miscastro33115_8.txt')
# (0, 'miscastro132213_17.txt')
# (0, 'miscastro192913_18.txt')
# (0, 'miscastro331118_9.txt')
# (0, 'miscastro192912_5.txt')
# (0, 'miscastro13229_9.txt')
# (0, 'miscastro132212_12.txt')
# (0, 'miscastro13228_2.txt')
# (0, 'miscastro13045_8.txt')
# (0, 'miscastro13047_13.txt')
# (0, 'miscastro13223_7.txt')
# (0, 'miscastro19293_16.txt')
# (0, 'miscastro130417_17.txt')
# (0, 'miscastro192911_2.txt')
# (0, 'miscastro13222_14.txt')
# (0, 'miscastro6303_6.txt')
# (0, 'miscastro331112_16.txt')
# (0, 'miscastro13040_16.txt')
# (0, 'miscastro331110_0.txt')
# (0, 'miscastro132213_19.txt')
# (0, 'miscastro63012_17.txt')
# (0, 'miscastro130411_13.txt')
# (0, 'miscastro192919_3.txt')
# (0, 'miscastro13227_7.txt')
# (0, 'miscastro331112_18.txt')
# (0, 'miscastro130414_11.txt')
# (0, 'miscastro6303_15.txt')
# (0, 'miscastro33116_5.txt')
# (0, 'miscastro19293_0.txt')
# (0, 'miscastro6308_2.txt')
# (0, 'miscastro19292_8.txt')
# (0, 'miscastro132210_12.txt')
# (0, 'miscastro33112_18.txt')
# (0, 'miscastro63012_8.txt')
# (0, 'miscastro132214_3.txt')
# (0, 'miscastro331119_2.txt')
# (0, 'miscastro331116_7.txt')
# (0, 'miscastro6306_14.txt')
# (0, 'miscastro192915_4.txt')
# (0, 'miscastro192914_19.txt')
# (0, 'miscastro19290_18.txt')
# (0, 'miscastro192914_12.txt')
# (0, 'miscastro130416_15.txt')
# (0, 'miscastro13043_18.txt')
# (0, 'miscastro192912_12.txt')
# (0, 'miscastro33116_12.txt')
# (0, 'miscastro6300_15.txt')
# (0, 'miscastro130415_6.txt')
# (0, 'miscastro132214_1.txt')
# (0, 'miscastro132213_9.txt')
# (0, 'miscastro6302_13.txt')
# (0, 'miscastro132213_4.txt')
# (0, 'miscastro192916_3.txt')
# (0, 'miscastro132211_19.txt')
# (0, 'miscastro132215_18.txt')
# (0, 'miscastro192918_16.txt')
# (0, 'miscastro33114_3.txt')
# (0, 'miscastro63015_9.txt')
# (0, 'miscastro192912_16.txt')
# (0, 'miscastro63017_3.txt')
# (0, 'miscastro13046_16.txt')
# (0, 'miscastro192912_10.txt')
# (0, 'miscastro63010_9.txt')
# (0, 'miscastro19293_5.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0577
#  - Using 5 steps per peak; omega_step = 0.0115
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 181415 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0669
#  - Using 5 steps per peak; omega_step = 0.0134
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 156516 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscastro132218_0.txt')
# (0, 'miscastro331115_3.txt')
# (0, 'miscastro331114_15.txt')
# (0, 'miscastro19295_13.txt')
# (0, 'miscastro132215_12.txt')
# (0, 'miscastro130412_3.txt')
# (0, 'miscastro13047_4.txt')
# (0, 'miscastro13045_12.txt')
# (0, 'miscastro132214_2.txt')
# (0, 'miscastro33114_10.txt')
# (0, 'miscastro130415_1.txt')
# (0, 'miscastro6305_5.txt')
# (0, 'miscastro331111_16.txt')
# (0, 'miscastro331119_18.txt')
# (0, 'miscastro331113_5.txt')
# (0, 'miscastro33116_18.txt')
# (0, 'miscastro19295_5.txt')
# (0, 'miscastro19290_15.txt')
# (0, 'miscastro132216_11.txt')
# (0, 'miscastro130410_13.txt')
# (0, 'miscastro132216_16.txt')
# (0, 'miscastro19294_7.txt')
# (0, 'miscastro33111_19.txt')
# (0, 'miscastro331116_16.txt')
# (0, 'miscastro63019_9.txt')
# (0, 'miscastro13225_14.txt')
# (0, 'miscastro63019_3.txt')
# (0, 'miscastro19292_16.txt')
# (0, 'miscastro13225_11.txt')
# (0, 'miscastro13040_4.txt')
# (0, 'miscastro132216_5.txt')
# (0, 'miscastro130415_12.txt')
# (0, 'miscastro6307_19.txt')
# (0, 'miscastro33114_15.txt')
# (0, 'miscastro132214_10.txt')
# (0, 'miscastro63010_13.txt')
# (0, 'miscastro13049_10.txt')
# (0, 'miscastro63015_14.txt')
# (0, 'miscastro33112_4.txt')
# (0, 'miscastro331115_0.txt')
# (0, 'miscastro130411_19.txt')
# (0, 'miscastro13042_1.txt')
# (0, 'miscastro130412_13.txt')
# (0, 'miscastro132213_2.txt')
# (0, 'miscastro63012_14.txt')
# (0, 'miscastro130416_11.txt')
# (0, 'miscastro13041_16.txt')
# (0, 'miscastro192916_9.txt')
# (0, 'miscastro130411_2.txt')
# (0, 'miscastro13224_11.txt')
# (0, 'miscastro130418_5.txt')
# (0, 'miscastro13223_8.txt')
# (0, 'miscastro13040_14.txt')
# (0, 'miscastro132215_10.txt')
# (0, 'miscastro130410_14.txt')
# (0, 'miscastro13049_3.txt')
# (0, 'miscastro19291_3.txt')
# (0, 'miscastro130410_10.txt')
# (0, 'miscastro13048_13.txt')
# (0, 'miscastro13046_2.txt')
# (0, 'miscastro130411_0.txt')
# (0, 'miscastro13220_8.txt')
# (0, 'miscastro19291_4.txt')
# (0, 'miscastro331116_6.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.0636
#  - Using 5 steps per peak; omega_step = 0.0127
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 164544 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro132210_13.txt')
# (0, 'miscastro132211_0.txt')
# (0, 'miscastro19292_2.txt')
# (0, 'miscastro192911_19.txt')
# (0, 'miscastro33117_12.txt')
# (0, 'miscastro130418_17.txt')
# (0, 'miscastro19296_15.txt')
# (0, 'miscastro130411_12.txt')
# (0, 'miscastro63013_4.txt')
# (0, 'miscastro13225_0.txt')
# (0, 'miscastro6301_5.txt')
# (0, 'miscastro132213_7.txt')
# (0, 'miscastro13041_12.txt')
# (0, 'miscastro33110_5.txt')
# (0, 'miscastro6303_0.txt')
# (0, 'miscastro63016_18.txt')
# (0, 'miscastro63011_9.txt')
# (0, 'miscastro19290_7.txt')
# (0, 'miscastro6304_19.txt')
# (0, 'miscastro130415_10.txt')
# (0, 'miscastro6301_9.txt')
# (0, 'miscastro130418_14.txt')
# (0, 'miscastro13044_3.txt')
# (0, 'miscastro19293_15.txt')
# (0, 'miscastro13047_2.txt')
# (0, 'miscastro13049_7.txt')
# (0, 'miscastro132217_6.txt')
# (0, 'miscastro192914_15.txt')
# (0, 'miscastro13047_19.txt')
# (0, 'miscastro13040_3.txt')
# (0, 'miscastro132218_13.txt')
# (0, 'miscastro63015_3.txt')
# (0, 'miscastro331110_14.txt')
# (0, 'miscastro130411_17.txt')
# (0, 'miscastro6301_1.txt')
# (0, 'miscastro331119_19.txt')
# (0, 'miscastro132218_12.txt')
# (0, 'miscastro6303_18.txt')
# (0, 'miscastro331119_1.txt')
# (0, 'miscastro132215_17.txt')
# (0, 'miscastro63011_8.txt')
# (0, 'miscastro33119_19.txt')
# (0, 'miscastro6309_9.txt')
# (0, 'miscastro6305_9.txt')
# (0, 'miscastro331117_12.txt')
# (0, 'miscastro13229_6.txt')
# (0, 'miscastro63016_6.txt')
# (0, 'miscastro6306_12.txt')
# (0, 'miscastro132212_17.txt')
# (0, 'miscastro331112_1.txt')
# (0, 'miscastro130411_15.txt')
# (0, 'miscastro63010_4.txt')
# (0, 'miscastro13046_15.txt')
# (0, 'miscastro19297_10.txt')
# (0, 'miscastro132214_16.txt')
# (0, 'miscastro33112_5.txt')
# (0, 'miscastro331110_4.txt')
# (0, 'miscastro63013_16.txt')
# (0, 'miscastro13225_3.txt')
# (0, 'miscastro13043_19.txt')
# (0, 'miscastro331112_2.txt')
# (0, 'miscastro132210_19.txt')
# (0, 'miscastro13229_4.txt')
# (0, 'miscastro13044_17.txt')
# (0, 'miscastro130417_15.txt')
# (0, 'miscastro33119_6.txt')
# (0, 'miscastro6303_19.txt')
# (0, 'miscastro19291_5.txt')
# (0, 'miscastro19291_11.txt')
# (0, 'miscastro13049_12.txt')
# (0, 'miscastro132212_2.txt')
# (0, 'miscastro19298_9.txt')
# (0, 'miscastro13224_13.txt')
# (0, 'miscastro33115_14.txt')
# (0, 'miscastro331116_9.txt')
# (0, 'miscastro331111_4.txt')
# (0, 'miscastro132211_9.txt')
# (0, 'miscastro13229_5.txt')
# (0, 'miscastro192914_7.txt')
# (0, 'miscastro130415_19.txt')
# (0, 'miscastro13043_11.txt')
# (0, 'miscastro192911_17.txt')
# (0, 'miscastro6301_4.txt')
# (0, 'miscastro331116_17.txt')
# (0, 'miscastro130412_1.txt')
# (0, 'miscastro192910_15.txt')
# (0, 'miscastro13042_17.txt')
# (0, 'miscastro13041_18.txt')
# (0, 'miscastro33111_9.txt')
# (0, 'miscastro33110_9.txt')
# (0, 'miscastro19295_9.txt')
# (0, 'miscastro6304_10.txt')
# (0, 'miscastro13048_5.txt')
# (0, 'miscastro6308_11.txt')
# (0, 'miscastro192911_12.txt')
# (0, 'miscastro33117_19.txt')
# (0, 'miscastro13223_17.txt')
# (0, 'miscastro130419_12.txt')
# (0, 'miscastro33118_3.txt')
# (0, 'miscastro130413_3.txt')
# (0, 'miscastro63012_16.txt')
# (0, 'miscastro331113_10.txt')
# (0, 'miscastro63018_1.txt')
# (0, 'miscastro19290_14.txt')
# (0, 'miscastro6304_11.txt')
# (0, 'miscastro63014_6.txt')
# (0, 'miscastro63019_8.txt')
# (0, 'miscastro130418_16.txt')
# (0, 'miscastro13223_5.txt')
# (0, 'miscastro130416_6.txt')
# (0, 'miscastro192915_19.txt')
# (0, 'miscastro33117_10.txt')
# (0, 'miscastro63010_8.txt')
# (0, 'miscastro19296_18.txt')
# (0, 'miscastro63012_18.txt')
# (0, 'miscastro6301_12.txt')
# (0, 'miscastro6304_1.txt')
# (0, 'miscastro132211_15.txt')
# (0, 'miscastro63010_7.txt')
# (0, 'miscastro132217_11.txt')
# (0, 'miscastro130412_5.txt')
# (0, 'miscastro63014_5.txt')
# (0, 'miscastro6300_2.txt')
# (0, 'miscastro6303_8.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5782328 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5757214 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro132212_8.txt')
# (0, 'miscastro13048_7.txt')
# (0, 'miscastro19296_14.txt')
# (0, 'miscastro13045_6.txt')
# (0, 'miscastro331117_4.txt')
# (0, 'miscastro63017_1.txt')
# (0, 'miscastro63019_14.txt')
# (0, 'miscastro331114_1.txt')
# (0, 'miscastro192913_11.txt')
# (0, 'miscastro13220_15.txt')
# (0, 'miscastro192916_16.txt')
# (0, 'miscastro13224_9.txt')
# (0, 'miscastro192918_4.txt')
# (0, 'miscastro19290_12.txt')
# (0, 'miscastro132216_10.txt')
# (0, 'miscastro63019_5.txt')
# (0, 'miscastro192918_7.txt')
# (0, 'miscastro6308_17.txt')
# (0, 'miscastro6309_5.txt')
# (0, 'miscastro63011_3.txt')
# (0, 'miscastro331112_4.txt')
# (0, 'miscastro6305_13.txt')
# (0, 'miscastro13040_18.txt')
# (0, 'miscastro192919_15.txt')
# (0, 'miscastro13228_6.txt')
# (0, 'miscastro130410_8.txt')
# (0, 'miscastro13041_1.txt')
# (0, 'miscastro132218_9.txt')
# (0, 'miscastro331114_14.txt')
# (0, 'miscastro331118_12.txt')
# (0, 'miscastro13226_16.txt')
# (0, 'miscastro192919_0.txt')
# (0, 'miscastro19296_9.txt')
# (0, 'miscastro132210_18.txt')
# (0, 'miscastro19298_10.txt')
# (0, 'miscastro33116_8.txt')
# (0, 'miscastro130412_16.txt')
# (0, 'miscastro63011_4.txt')
# (0, 'miscastro19294_10.txt')
# (0, 'miscastro33117_5.txt')
# (0, 'miscastro130416_7.txt')
# (0, 'miscastro130412_11.txt')
# (0, 'miscastro331111_9.txt')
# (0, 'miscastro132211_13.txt')
# (0, 'miscastro13049_1.txt')
# (0, 'miscastro130411_11.txt')
# (0, 'miscastro13222_12.txt')
# (0, 'miscastro63011_0.txt')
# (0, 'miscastro192919_16.txt')
# (0, 'miscastro63019_18.txt')
# (0, 'miscastro132213_11.txt')
# (0, 'miscastro130419_18.txt')
# (0, 'miscastro19291_9.txt')
# (0, 'miscastro130413_8.txt')
# (0, 'miscastro33111_14.txt')
# (0, 'miscastro19294_12.txt')
# (0, 'miscastro33116_4.txt')
# (0, 'miscastro192914_16.txt')
# (0, 'miscastro331113_2.txt')
# (0, 'miscastro192917_11.txt')
# (0, 'miscastro130414_18.txt')
# (0, 'miscastro6306_6.txt')
# (0, 'miscastro331111_0.txt')
# (0, 'miscastro132211_4.txt')
# (0, 'miscastro63013_5.txt')
# (0, 'miscastro13227_2.txt')
# (0, 'miscastro63015_10.txt')
# (0, 'miscastro33116_14.txt')
# (0, 'miscastro132212_19.txt')
# (0, 'miscastro192911_9.txt')
# (0, 'miscastro6300_18.txt')
# (0, 'miscastro13220_19.txt')
# (0, 'miscastro13227_5.txt')
# (0, 'miscastro13048_8.txt')
# (0, 'miscastro13227_10.txt')
# (0, 'miscastro19299_18.txt')
# (0, 'miscastro331117_13.txt')
# (0, 'miscastro331115_4.txt')
# (0, 'miscastro33110_0.txt')
# (0, 'miscastro6307_9.txt')
# (0, 'miscastro192918_10.txt')
# (0, 'miscastro192919_10.txt')
# (0, 'miscastro6300_3.txt')
# (0, 'miscastro331112_10.txt')
# (0, 'miscastro132217_8.txt')
# (0, 'miscastro192913_7.txt')
# (0, 'miscastro63017_16.txt')
# (0, 'miscastro192912_8.txt')
# (0, 'miscastro192915_11.txt')
# (0, 'miscastro192919_4.txt')
# (0, 'miscastro33115_16.txt')
# (0, 'miscastro331112_5.txt')
# (0, 'miscastro19295_4.txt')
# (0, 'miscastro331119_3.txt')
# (0, 'miscastro192910_14.txt')
# (0, 'miscastro192917_10.txt')
# (0, 'miscastro130419_2.txt')
# (0, 'miscastro192916_19.txt')
# (0, 'miscastro13220_6.txt')
# (0, 'miscastro63015_18.txt')
# (0, 'miscastro19299_9.txt')
# (0, 'miscastro130412_12.txt')
# (0, 'miscastro13227_4.txt')
# (0, 'miscastro130412_14.txt')
# (0, 'miscastro19293_7.txt')
# (0, 'miscastro331115_14.txt')
# (0, 'miscastro63013_11.txt')
# (0, 'miscastro192919_18.txt')
# (0, 'miscastro132215_8.txt')
# (0, 'miscastro13227_18.txt')
# (0, 'miscastro130412_17.txt')
# (0, 'miscastro331113_17.txt')
# (0, 'miscastro192918_1.txt')
# ...
# (0, 'miscastro130416_1.txt')
# (0, 'miscastro132212_10.txt')
# (0, 'miscastro63014_9.txt')
# (0, 'miscastro13049_2.txt')
# (0, 'miscastro130411_1.txt')
# (0, 'miscastro13043_10.txt')
# (0, 'miscastro33118_19.txt')
# (0, 'miscastro132212_18.txt')
# (0, 'miscastro132213_10.txt')
# (0, 'miscastro132213_14.txt')
# (0, 'miscastro13225_12.txt')
# (0, 'miscastro19295_0.txt')
# (0, 'miscastro63015_15.txt')
# (0, 'miscastro13224_18.txt')
# (0, 'miscastro6302_11.txt')
# (0, 'miscastro13043_0.txt')
# (0, 'miscastro13228_17.txt')
# (0, 'miscastro13042_14.txt')
# (0, 'miscastro192914_8.txt')
# (0, 'miscastro331110_1.txt')
# (0, 'miscastro132215_15.txt')
# (0, 'miscastro13040_15.txt')
# (0, 'miscastro331116_1.txt')
# (0, 'miscastro331118_11.txt')
# (0, 'miscastro331110_10.txt')
# (0, 'miscastro19296_11.txt')
# (0, 'miscastro13228_12.txt')
# (0, 'miscastro13229_2.txt')
# (0, 'miscastro13042_2.txt')
# (0, 'miscastro6300_4.txt')
# (0, 'miscastro192916_12.txt')
# (0, 'miscastro19293_4.txt')
# (0, 'miscastro19296_6.txt')
# (0, 'miscastro6307_13.txt')
# (0, 'miscastro13044_7.txt')
# (0, 'miscastro130412_19.txt')
# (0, 'miscastro331111_11.txt')
# (0, 'miscastro130419_1.txt')
# (0, 'miscastro63013_7.txt')
# (0, 'miscastro192915_16.txt')
# (0, 'miscastro331112_17.txt')
# (0, 'miscastro19299_2.txt')
# (0, 'miscastro33118_13.txt')
# (0, 'miscastro33118_5.txt')
# (0, 'miscastro331116_0.txt')
# (0, 'miscastro13041_2.txt')
# (0, 'miscastro6303_1.txt')
# (0, 'miscastro63018_10.txt')
# (0, 'miscastro33119_2.txt')
# (0, 'miscastro19296_8.txt')
# (0, 'miscastro6303_13.txt')
# (0, 'miscastro33113_15.txt')
# (0, 'miscastro6304_17.txt')
# (0, 'miscastro13046_18.txt')
# (0, 'miscastro63019_11.txt')
# (0, 'miscastro192917_9.txt')
# (0, 'miscastro132212_16.txt')
# (0, 'miscastro33118_10.txt')
# (0, 'miscastro130412_7.txt')
# (0, 'miscastro132210_8.txt')
# (0, 'miscastro33116_0.txt')
# (0, 'miscastro331117_6.txt')
# (0, 'miscastro33113_13.txt')
# (0, 'miscastro33114_18.txt')
# (0, 'miscastro132215_2.txt')
# (0, 'miscastro331119_6.txt')
# (0, 'miscastro13047_15.txt')
# (0, 'miscastro192916_4.txt')
# (0, 'miscastro19298_16.txt')
# (0, 'miscastro130416_0.txt')
# (0, 'miscastro13042_0.txt')
# (0, 'miscastro130412_4.txt')
# (0, 'miscastro192910_9.txt')
# (0, 'miscastro6309_14.txt')
# (0, 'miscastro13046_13.txt')
# (0, 'miscastro132219_15.txt')
# (0, 'miscastro331119_11.txt')
# (0, 'miscastro132219_7.txt')
# (0, 'miscastro331117_0.txt')
# (0, 'miscastro132213_16.txt')
# (0, 'miscastro331113_0.txt')
# (0, 'miscastro33117_9.txt')
# (0, 'miscastro13049_5.txt')
# (0, 'miscastro192916_2.txt')
# (0, 'miscastro192912_18.txt')
# (0, 'miscastro331116_18.txt')
# (0, 'miscastro13048_15.txt')
# (0, 'miscastro13049_9.txt')
# (0, 'miscastro6304_9.txt')
# (0, 'miscastro130416_12.txt')
# (0, 'miscastro13228_15.txt')
# (0, 'miscastro13228_9.txt')
# (0, 'miscastro132212_13.txt')
# (0, 'miscastro192911_11.txt')
# (0, 'miscastro13047_7.txt')
# (0, 'miscastro63013_13.txt')
# (0, 'miscastro33110_2.txt')
# (0, 'miscastro192914_17.txt')
# (0, 'miscastro6300_5.txt')
# (0, 'miscastro13227_16.txt')
# (0, 'miscastro6301_14.txt')
# (0, 'miscastro63017_12.txt')
# (0, 'miscastro132219_3.txt')
# (0, 'miscastro63012_10.txt')
# (0, 'miscastro19299_8.txt')
# (0, 'miscastro130410_6.txt')
# (0, 'miscastro33111_11.txt')
# (0, 'miscastro13046_11.txt')
# (0, 'miscastro132219_6.txt')
# (0, 'miscastro192912_6.txt')
# (0, 'miscastro19293_8.txt')
# (0, 'miscastro63016_5.txt')
# (0, 'miscastro33116_7.txt')
# (0, 'miscastro13040_1.txt')
# (0, 'miscastro6303_14.txt')
# (0, 'miscastro331118_10.txt')
# (0, 'miscastro6308_13.txt')
# (0, 'miscastro13047_1.txt')
# (0, 'miscastro6305_1.txt')
# (0, 'miscastro19291_6.txt')
# (0, 'miscastro132219_16.txt')
# (0, 'miscastro331112_9.txt')
# (0, 'miscastro132213_6.txt')
# (0, 'miscastro19298_1.txt')
# (0, 'miscastro33114_8.txt')
# (0, 'miscastro331111_13.txt')
# (0, 'miscastro132214_19.txt')
# (0, 'miscastro192910_3.txt')
# (0, 'miscastro13043_9.txt')
# (0, 'miscastro63019_2.txt')
# (0, 'miscastro19299_0.txt')
# (0, 'miscastro130415_16.txt')
# (0, 'miscastro6300_6.txt')
# (0, 'miscastro331117_8.txt')
# (0, 'miscastro13041_8.txt')
# (0, 'miscastro19296_5.txt')
# (0, 'miscastro19295_12.txt')
# (0, 'miscastro331115_19.txt')
# (0, 'miscastro130417_16.txt')
# (0, 'miscastro13229_7.txt')
# (0, 'miscastro130414_6.txt')
# (0, 'miscastro331115_8.txt')
# (0, 'miscastro331117_10.txt')
# (0, 'miscastro13040_0.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5782328 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5782328 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0636
#  - Using 5 steps per peak; omega_step = 0.0127
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 164544 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscastro19292_12.txt')
# (0, 'miscastro6309_12.txt')
# (0, 'miscastro63017_15.txt')
# (0, 'miscastro13049_17.txt')
# (0, 'miscastro13047_0.txt')
# (0, 'miscastro13221_14.txt')
# (0, 'miscastro6301_7.txt')
# (0, 'miscastro13040_2.txt')
# (0, 'miscastro33110_8.txt')
# (0, 'miscastro6307_7.txt')
# (0, 'miscastro192919_14.txt')
# (0, 'miscastro6306_11.txt')
# (0, 'miscastro130415_13.txt')
# (0, 'miscastro130410_9.txt')
# (0, 'miscastro192919_7.txt')
# (0, 'miscastro33118_12.txt')
# (0, 'miscastro132213_5.txt')
# (0, 'miscastro63014_15.txt')
# (0, 'miscastro19297_19.txt')
# (0, 'miscastro13040_13.txt')
# (0, 'miscastro132218_15.txt')
# (0, 'miscastro130411_4.txt')
# (0, 'miscastro33117_17.txt')
# (0, 'miscastro33118_2.txt')
# (0, 'miscastro132213_18.txt')
# (0, 'miscastro33110_13.txt')
# (0, 'miscastro130412_2.txt')
# (0, 'miscastro63016_3.txt')
# (0, 'miscastro19298_12.txt')
# (0, 'miscastro132219_2.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5760667 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5782328 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscastro132212_1.txt')
# (0, 'miscastro192916_10.txt')
# (0, 'miscastro13042_19.txt')
# (0, 'miscastro192918_8.txt')
# (0, 'miscastro33119_9.txt')
# (0, 'miscastro192915_6.txt')
# (0, 'miscastro331117_1.txt')
# (0, 'miscastro192913_9.txt')
# (0, 'miscastro331119_5.txt')
# (0, 'miscastro192912_17.txt')
# (0, 'miscastro13222_10.txt')
# (0, 'miscastro63018_3.txt')
# (0, 'miscastro33113_4.txt')
# (0, 'miscastro192916_8.txt')
# (0, 'miscastro6300_8.txt')
# (0, 'miscastro33117_1.txt')
# (0, 'miscastro13225_19.txt')
# (0, 'miscastro33116_13.txt')
# (0, 'miscastro33114_14.txt')
# (0, 'miscastro33118_7.txt')
# (0, 'miscastro6305_18.txt')
# (0, 'miscastro33119_8.txt')
# (0, 'miscastro192916_5.txt')
# (0, 'miscastro13223_9.txt')
# (0, 'miscastro13045_14.txt')
# (0, 'miscastro13228_0.txt')
# (0, 'miscastro13228_7.txt')
# (0, 'miscastro132210_9.txt')
# (0, 'miscastro331113_18.txt')
# (0, 'miscastro33111_7.txt')
# (0, 'miscastro331111_7.txt')
# (0, 'miscastro331110_13.txt')
# (0, 'miscastro130413_0.txt')
# (0, 'miscastro130415_2.txt')
# (0, 'miscastro192915_9.txt')
# (0, 'miscastro19296_2.txt')
# (0, 'miscastro192912_7.txt')
# (0, 'miscastro6303_2.txt')
# (0, 'miscastro192916_15.txt')
# (0, 'miscastro19297_13.txt')
# (0, 'miscastro19294_1.txt')
# (0, 'miscastro192915_10.txt')
# (0, 'miscastro132219_13.txt')
# (0, 'miscastro132217_3.txt')
# (0, 'miscastro19296_7.txt')
# (0, 'miscastro132214_7.txt')
# (0, 'miscastro331116_12.txt')
# (0, 'miscastro192919_2.txt')
# (0, 'miscastro132217_13.txt')
# (0, 'miscastro132214_13.txt')
# (0, 'miscastro6301_18.txt')
# (0, 'miscastro33111_16.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5787180 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00192
#  - Using 5 steps per peak; omega_step = 0.000383
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5461031 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00181
#  - Using 5 steps per peak; omega_step = 0.000362
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5782328 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000364
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5756996 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscastro13229_12.txt')
# (0, 'miscastro13227_14.txt')
# (0, 'miscastro19297_2.txt')
# (0, 'miscastro19294_0.txt')
# (0, 'miscastro132216_2.txt')
# (0, 'miscastro33114_16.txt')
# (0, 'miscastro13049_6.txt')
# (0, 'miscastro63013_9.txt')
# (0, 'miscastro33119_7.txt')
# (0, 'miscastro19291_8.txt')
# (0, 'miscastro13228_16.txt')
# (0, 'miscastro192918_6.txt')
# (0, 'miscastro63010_11.txt')
# (0, 'miscastro130411_7.txt')
# (0, 'miscastro130413_1.txt')
# (0, 'miscastro63016_0.txt')
# (0, 'miscastro192913_0.txt')
# (0, 'miscastro132211_11.txt')
# (0, 'miscastro63011_10.txt')
# (0, 'miscastro19299_17.txt')
# (0, 'miscastro130419_0.txt')
# (0, 'miscastro13049_8.txt')
# (0, 'miscastro33114_2.txt')
# (0, 'miscastro331116_4.txt')
# (0, 'miscastro19293_9.txt')
# (0, 'miscastro130417_18.txt')
# (0, 'miscastro19296_19.txt')
# (0, 'miscastro6307_5.txt')
# (0, 'miscastro6309_15.txt')
# (0, 'miscastro33113_2.txt')
# (0, 'miscastro63011_2.txt')
# (0, 'miscastro6305_11.txt')
# (0, 'miscastro132216_4.txt')
# (0, 'miscastro6302_17.txt')
# (0, 'miscastro13220_17.txt')
# (0, 'miscastro130410_1.txt')
# (0, 'miscastro331117_3.txt')
# (0, 'miscastro331110_17.txt')
# (0, 'miscastro63018_14.txt')
# (0, 'miscastro19295_10.txt')
# (0, 'miscastro33117_16.txt')
# (0, 'miscastro33111_18.txt')
# (0, 'miscastro132211_7.txt')
# (0, 'miscastro13223_15.txt')
# (0, 'miscastro19298_4.txt')
# (0, 'miscastro13042_13.txt')
# (0, 'miscastro13224_0.txt')
# (0, 'miscastro6308_16.txt')
# (0, 'miscastro19295_1.txt')
# (0, 'miscastro13222_15.txt')
# (0, 'miscastro132210_3.txt')
# (0, 'miscastro6305_8.txt')
# (0, 'miscastro63011_12.txt')
# (0, 'miscastro331111_19.txt')
# (0, 'miscastro63010_2.txt')
# (0, 'miscastro13044_5.txt')
# (0, 'miscastro130418_4.txt')
# (0, 'miscastro33118_14.txt')
# (0, 'miscastro130417_10.txt')
# (0, 'miscastro192910_8.txt')
# (0, 'miscastro6302_10.txt')
# (0, 'miscastro6306_15.txt')
# (0, 'miscastro19294_19.txt')
# (0, 'miscastro331118_2.txt')
# (0, 'miscastro331112_14.txt')
# (0, 'miscastro13228_4.txt')
# (0, 'miscastro331110_3.txt')
# (0, 'miscastro132217_0.txt')
# (0, 'miscastro132219_11.txt')
# (0, 'miscastro6306_9.txt')
# (0, 'miscastro63012_9.txt')
# (0, 'miscastro63016_16.txt')
# (0, 'miscastro6302_12.txt')
# (0, 'miscastro19292_1.txt')
# (0, 'miscastro6302_19.txt')
# (0, 'miscastro130416_10.txt')
# (0, 'miscastro63013_2.txt')
# (0, 'miscastro33113_12.txt')
# (0, 'miscastro192912_19.txt')
# (0, 'miscastro13221_12.txt')
# (0, 'miscastro192917_14.txt')
# (0, 'miscastro13041_14.txt')
# (0, 'miscastro331110_5.txt')
# (0, 'miscastro13041_5.txt')
# (0, 'miscastro13049_14.txt')
# (0, 'miscastro19295_11.txt')
# (0, 'miscastro132213_0.txt')
# (0, 'miscastro132214_8.txt')
# (0, 'miscastro13226_9.txt')
# (0, 'miscastro6308_7.txt')
# (0, 'miscastro63012_4.txt')
# (0, 'miscastro6306_17.txt')
# (0, 'miscastro192914_1.txt')
# (0, 'miscastro331118_1.txt')
# (0, 'miscastro19299_16.txt')
# (0, 'miscastro19290_2.txt')
# (0, 'miscastro6302_7.txt')
# (0, 'miscastro132210_5.txt')
# (0, 'miscastro33110_3.txt')
# (0, 'miscastro63014_14.txt')
# (0, 'miscastro6301_13.txt')
# (0, 'miscastro6307_1.txt')
# (0, 'miscastro132219_1.txt')
# (0, 'miscastro132214_17.txt')
# (0, 'miscastro132216_6.txt')
# (0, 'miscastro192918_17.txt')
# (0, 'miscastro192918_19.txt')
# (0, 'miscastro19293_12.txt')
# (0, 'miscastro33115_2.txt')
# (0, 'miscastro13048_10.txt')
# (0, 'miscastro13042_5.txt')
# (0, 'miscastro130413_7.txt')
# (0, 'miscastro63011_13.txt')
# (0, 'miscastro19294_17.txt')
# (0, 'miscastro13229_13.txt')
# (0, 'miscastro6309_13.txt')
# (0, 'miscastro132211_1.txt')
# (0, 'miscastro33116_15.txt')
# (0, 'miscastro63018_13.txt')
# (0, 'miscastro13045_4.txt')
# (0, 'miscastro63014_0.txt')
# (0, 'miscastro192914_6.txt')
# (0, 'miscastro13226_8.txt')
# (0, 'miscastro13227_9.txt')
# (0, 'miscastro19290_8.txt')
# (0, 'miscastro33116_2.txt')
# (0, 'miscastro63018_0.txt')
# (0, 'miscastro13229_17.txt')
# (0, 'miscastro13223_11.txt')
# (0, 'miscastro13223_14.txt')
# (0, 'miscastro192919_8.txt')
# (0, 'miscastro19291_17.txt')
# (0, 'miscastro13049_0.txt')
# (0, 'miscastro6304_8.txt')
# (0, 'miscastro132215_14.txt')
# (0, 'miscastro63015_11.txt')
# (0, 'miscastro13227_17.txt')
# (0, 'miscastro63019_12.txt')
# (0, 'miscastro132219_14.txt')
# (0, 'miscastro13227_11.txt')
# (0, 'miscastro331113_16.txt')
# (0, 'miscastro13222_9.txt')
# (0, 'miscastro13227_1.txt')
# (0, 'miscastro19299_10.txt')
# (0, 'miscastro130411_9.txt')
# (0, 'miscastro63018_18.txt')
# (0, 'miscastro13223_1.txt')
# (0, 'miscastro130418_0.txt')
# (0, 'miscastro19290_10.txt')
# (0, 'miscastro33110_18.txt')
# (0, 'miscastro13043_16.txt')
# (0, 'miscastro13044_16.txt')
# (0, 'miscastro132217_1.txt')
# (0, 'miscastro33112_2.txt')
# (0, 'miscastro33110_14.txt')
# (0, 'miscastro19295_14.txt')
# (0, 'miscastro33115_12.txt')
# (0, 'miscastro33114_5.txt')

# %%
print(misclist[0][:-3])
# Out:
# miscastro19298_17.

# %%
temporaryFile.py
