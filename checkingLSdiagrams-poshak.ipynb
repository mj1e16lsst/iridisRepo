# %%
import subprocess
import os
import matplotlib.pyplot as plt
from gatspy import periodic
import numpy as np

# %%
dirlist = os.listdir('./poshak')

# %%
misclist = [x for x in dirlist if 'misc' in x]

# %%
colours = {'u':'blue','g':'green','r':'red','i':'orange','z':'yellow','y':'black'}

# %%
periodlist = np.logspace(-2.5,1.4)
numsteps = 1000000
fmin = periodlist[0]
df = (periodlist[-1]-periodlist[0])/numsteps

for x in range(len(misclist)):
    
    finder1 = '_'
    finder2 = '.'
    loc1 = misclist[x].find(finder1)
    loc2 = misclist[x].find(finder2)
    number = misclist[x][loc1+1:loc2]
    try:
        number = int(number)
    except ValueError:
        print(number)
    os.chdir('/home/mj1e16/iridisRepo/poshak')
    f = open(misclist[x],'r')
    filestring = f.read()
    f.close()
    filestring = filestring.replace(" ",",")
    filestring = filestring.replace(",,,",",")
    filestring = filestring.replace(",,",",")
    filestring = filestring.replace(",=,","=")
    filestring = filestring.replace("[,","[")
    filestring = filestring.replace(",,",",")
    filestring = filestring.replace(",\n",",")
    filestring = filestring.replace("sampledLC","#sampledLC")
    filestring = filestring.replace("\maxpowers","#\maxpowers")
    f = open('temporaryFile.py','w')
    f.write(filestring)
    f.close()
    if x ==0:
        import temporaryFile
    else:
        reload(temporaryFile)
    date = temporaryFile.date
    mag = temporaryFile.mag
    error = temporaryFile.error
    filters = temporaryFile.filts
    if len(date) != 0:
        freqs = fmin + df * np.arange(numsteps) 
        model = periodic.LombScargleMultibandFast(fit_period=False)
        model.fit(date, mag, error, filters)
        power = model.score_frequency_grid(fmin, df, numsteps) 
        model.optimizer.period_range=(0.003, 26)
        LSperiod = model.best_period
        fig, ax = plt.subplots()
        ax.plot(np.log10(freqs), np.log10(power))
        ax.set(xlabel='period (days)',
               ylabel='Lomb-Scargle Power',
              title='Period = '+str(periodlist[number])+', MeasuredPeriod = '+str(LSperiod))
        plt.show()
        for y in range(len(date)):
            plt.plot(date[y],mag[y],'o',color=colours[filters[y]],markersize=1.5)
        plt.show()
    else:
        print(len(date),misclist[x])
# Out:
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# /home/mj1e16/miniconda2/envs/astroconda/lib/python2.7/site-packages/gatspy/periodic/lomb_scargle_fast.py:429: UserWarning: For smaller datasets, the approximation used by LombScargleFast may not be suitable.
# It is recommended to use LombScargle instead.
# To silence this warning, set ``silence_warnings=True``
#   warnings.warn("For smaller datasets, the approximation used by "
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5707476 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscpanstars132216_6.txt')
# (0, 'miscpanstars331114_5.txt')
# (0, 'miscpanstars63014_10.txt')
# (0, 'miscpanstars331110_11.txt')
# (0, 'miscpanstars192919_16.txt')
# (0, 'miscpanstars130410_8.txt')
# (0, 'miscpanstars13224_9.txt')
# (0, 'miscpanstars331117_10.txt')
# (0, 'miscpanstars192913_6.txt')
# (0, 'miscastro13042_18.txt')
# (0, 'miscastro130411_8.txt')
# (0, 'miscpanstars6304_18.txt')
# (0, 'miscpanstars33111_9.txt')
# (0, 'miscpanstars13045_6.txt')
# (0, 'miscpanstars331119_16.txt')
# (0, 'miscpanstars130419_8.txt')
# (0, 'miscpanstars13040_16.txt')
# (0, 'miscpanstars63014_5.txt')
# (0, 'miscpanstars33114_13.txt')
# (0, 'miscpanstars6303_17.txt')
# (0, 'miscpanstars132210_18.txt')
# (0, 'miscpanstars13046_15.txt')
# (0, 'miscpanstars192918_5.txt')
# (0, 'miscpanstars33116_12.txt')
# (0, 'miscpanstars63010_5.txt')
# (0, 'miscpanstars13046_0.txt')
# (0, 'miscpanstars33114_6.txt')
# (0, 'miscpanstars63019_19.txt')
# (0, 'miscpanstars63015_2.txt')
# (0, 'miscpanstars331111_9.txt')
# (0, 'miscpanstars192912_2.txt')
# (0, 'miscpanstars130410_13.txt')
# (0, 'miscpanstars33114_3.txt')
# (0, 'miscpanstars132214_12.txt')
# (0, 'miscpanstars130416_13.txt')
# (0, 'miscpanstars132210_8.txt')
# (0, 'miscpanstars132219_13.txt')
# (0, 'miscpanstars192911_6.txt')
# (0, 'miscpanstars192916_6.txt')
# (0, 'miscpanstars63015_16.txt')
# (0, 'miscpanstars13223_4.txt')
# (0, 'miscpanstars132215_5.txt')
# (0, 'miscpanstars192915_15.txt')
# (0, 'miscpanstars13043_2.txt')
# (0, 'miscpanstars19298_16.txt')
# (0, 'miscpanstars331114_13.txt')
# (0, 'miscpanstars130416_1.txt')
# (0, 'miscpanstars130419_3.txt')
# (0, 'miscpanstars33110_2.txt')
# (0, 'miscpanstars130414_7.txt')
# (0, 'miscpanstars63018_7.txt')
# (0, 'miscpanstars63015_4.txt')
# (0, 'miscpanstars63011_6.txt')
# (0, 'miscpanstars13042_2.txt')
# (0, 'miscpanstars130411_9.txt')
# (0, 'miscpanstars63019_6.txt')
# (0, 'miscpanstars331111_8.txt')
# (0, 'miscpanstars130416_9.txt')
# (0, 'miscpanstars13222_11.txt')
# (0, 'miscpanstars331111_14.txt')
# (0, 'miscastro13041_19.txt')
# (0, 'miscpanstars13041_17.txt')
# (0, 'miscpanstars132212_4.txt')
# (0, 'miscpanstars13043_17.txt')
# (0, 'miscpanstars130418_14.txt')
# (0, 'miscpanstars331116_1.txt')
# (0, 'miscpanstars192910_3.txt')
# (0, 'miscpanstars33114_2.txt')
# (0, 'miscpanstars63016_3.txt')
# (0, 'miscpanstars63017_18.txt')
# (0, 'miscpanstars13226_2.txt')
# (0, 'miscpanstars13225_15.txt')
# (0, 'miscpanstars132218_0.txt')
# (0, 'miscpanstars130413_13.txt')
# (0, 'miscpanstars13228_18.txt')
# (0, 'miscpanstars192917_15.txt')
# (0, 'miscpanstars192914_4.txt')
# (0, 'miscpanstars13222_8.txt')
# (0, 'miscpanstars13048_19.txt')
# (0, 'miscpanstars132216_19.txt')
# (0, 'miscpanstars13224_18.txt')
# (0, 'miscpanstars192914_6.txt')
# (0, 'miscpanstars33115_11.txt')
# (0, 'miscpanstars132214_13.txt')
# (0, 'miscpanstars130416_5.txt')
# (0, 'miscpanstars13227_2.txt')
# (0, 'miscpanstars19293_2.txt')
# (0, 'miscpanstars19298_13.txt')
# (0, 'miscpanstars6306_5.txt')
# (0, 'miscpanstars13047_11.txt')
# (0, 'miscpanstars132212_9.txt')
# (0, 'miscpanstars19298_14.txt')
# (0, 'miscpanstars13228_10.txt')
# (0, 'miscpanstars192910_13.txt')
# (0, 'miscpanstars132218_10.txt')
# (0, 'miscpanstars33113_12.txt')
# (0, 'miscpanstars132216_1.txt')
# (0, 'miscpanstars6301_13.txt')
# (0, 'miscpanstars13048_7.txt')
# (0, 'miscpanstars6302_12.txt')
# (0, 'miscpanstars130410_0.txt')
# (0, 'miscastro130411_16.txt')
# (0, 'miscpanstars331111_13.txt')
# (0, 'miscpanstars19295_2.txt')
# (0, 'miscpanstars331116_3.txt')
# (0, 'miscpanstars331116_0.txt')
# (0, 'miscpanstars19292_9.txt')
# (0, 'miscpanstars130410_16.txt')
# (0, 'miscpanstars130415_9.txt')
# (0, 'miscpanstars33114_5.txt')
# (0, 'miscpanstars13220_14.txt')
# (0, 'miscpanstars6305_0.txt')
# (0, 'miscpanstars13224_14.txt')
# (0, 'miscpanstars192919_12.txt')
# (0, 'miscpanstars33110_1.txt')
# (0, 'miscpanstars192910_17.txt')
# (0, 'miscpanstars6308_0.txt')
# (0, 'miscastro13043_1.txt')
# (0, 'miscpanstars13223_14.txt')
# (0, 'miscpanstars13229_1.txt')
# (0, 'miscpanstars192911_7.txt')
# (0, 'miscastro13041_0.txt')
# (0, 'miscpanstars6300_19.txt')
# (0, 'miscpanstars33118_19.txt')
# (0, 'miscpanstars331116_18.txt')
# (0, 'miscpanstars63012_5.txt')
# (0, 'miscpanstars331114_2.txt')
# (0, 'miscpanstars130412_11.txt')
# (0, 'miscpanstars192915_10.txt')
# (0, 'miscpanstars192915_17.txt')
# (0, 'miscpanstars132216_17.txt')
# (0, 'miscpanstars6307_7.txt')
# (0, 'miscpanstars331117_3.txt')
# (0, 'miscpanstars13224_6.txt')
# (0, 'miscastro13040_19.txt')
# (0, 'miscpanstars33112_5.txt')
# (0, 'miscpanstars19299_13.txt')
# (0, 'miscpanstars130415_18.txt')
# (0, 'miscpanstars132218_1.txt')
# (0, 'miscpanstars13226_17.txt')
# (0, 'miscpanstars331111_15.txt')
# (0, 'miscpanstars130413_3.txt')
# (0, 'miscpanstars6306_0.txt')
# (0, 'miscpanstars13041_10.txt')
# (0, 'miscpanstars132212_17.txt')
# (0, 'miscpanstars130411_8.txt')
# (0, 'miscpanstars33112_2.txt')
# (0, 'miscpanstars192913_17.txt')
# (0, 'miscpanstars130410_11.txt')
# (0, 'miscpanstars192913_0.txt')
# (0, 'miscpanstars130419_13.txt')
# (0, 'miscpanstars192911_12.txt')
# (0, 'miscpanstars13044_10.txt')
# (0, 'miscpanstars13041_13.txt')
# (0, 'miscpanstars132212_11.txt')
# (0, 'miscpanstars130412_5.txt')
# (0, 'miscpanstars13220_5.txt')
# (0, 'miscpanstars132219_19.txt')
# (0, 'miscpanstars13046_1.txt')
# (0, 'miscpanstars331112_18.txt')
# (0, 'miscpanstars6301_4.txt')
# (0, 'miscbaseline19298_15.txt')
# (0, 'miscpanstars63019_7.txt')
# (0, 'miscpanstars132211_9.txt')
# (0, 'miscpanstars130419_5.txt')
# (0, 'miscpanstars19299_10.txt')
# (0, 'miscpanstars63012_2.txt')
# (0, 'miscpanstars33117_7.txt')
# (0, 'miscpanstars19293_13.txt')
# (0, 'miscpanstars192913_5.txt')
# (0, 'miscpanstars130418_11.txt')
# (0, 'miscpanstars19298_19.txt')
# (0, 'miscpanstars63016_10.txt')
# (0, 'miscpanstars331117_9.txt')
# (0, 'miscpanstars13221_15.txt')
# (0, 'miscpanstars19296_12.txt')
# (0, 'miscpanstars130418_12.txt')
# (0, 'miscpanstars63016_18.txt')
# (0, 'miscpanstars13223_0.txt')
# (0, 'miscpanstars331112_8.txt')
# (0, 'miscpanstars331118_3.txt')
# (0, 'miscpanstars130416_17.txt')
# (0, 'miscpanstars33116_10.txt')
# (0, 'miscpanstars130418_3.txt')
# (0, 'miscpanstars132217_10.txt')
# (0, 'miscpanstars13042_5.txt')
# (0, 'miscpanstars13040_0.txt')
# (0, 'miscpanstars192911_11.txt')
# (0, 'miscpanstars132215_8.txt')
# (0, 'miscpanstars192913_7.txt')
# (0, 'miscpanstars13225_11.txt')
# (0, 'miscpanstars63018_16.txt')
# (0, 'miscpanstars13048_6.txt')
# (0, 'miscpanstars19296_13.txt')
# (0, 'miscpanstars13223_6.txt')
# (0, 'miscpanstars63019_8.txt')
# (0, 'miscpanstars33119_10.txt')
# (0, 'miscpanstars19297_12.txt')
# (0, 'miscpanstars19292_8.txt')
# (0, 'miscastro130412_6.txt')
# (0, 'miscpanstars192912_17.txt')
# (0, 'miscpanstars6303_14.txt')
# (0, 'miscpanstars132211_1.txt')
# (0, 'miscpanstars63017_7.txt')
# (0, 'miscpanstars19290_7.txt')
# (0, 'miscpanstars192911_14.txt')
# (0, 'miscpanstars33119_19.txt')
# (0, 'miscpanstars331118_17.txt')
# (0, 'miscpanstars19294_3.txt')
# (0, 'miscastro130411_10.txt')
# (0, 'miscpanstars13042_10.txt')
# (0, 'miscpanstars13221_4.txt')
# (0, 'miscpanstars13041_7.txt')
# (0, 'miscpanstars132214_10.txt')
# (0, 'miscpanstars19295_6.txt')
# (0, 'miscpanstars13046_18.txt')
# (0, 'miscpanstars63012_11.txt')
# (0, 'miscpanstars13040_10.txt')
# (0, 'miscastro13041_4.txt')
# (0, 'miscpanstars33116_14.txt')
# (0, 'miscpanstars192912_1.txt')
# (0, 'miscpanstars132218_4.txt')
# (0, 'miscpanstars192915_1.txt')
# (0, 'miscpanstars13041_19.txt')
# (0, 'miscpanstars19291_8.txt')
# (0, 'miscpanstars13049_10.txt')
# (0, 'miscpanstars13229_9.txt')
# (0, 'miscpanstars6304_16.txt')
# (0, 'miscpanstars63016_6.txt')
# (0, 'miscpanstars130418_6.txt')
# (0, 'miscpanstars331110_9.txt')
# (0, 'miscpanstars130418_10.txt')
# (0, 'miscpanstars33113_5.txt')
# (0, 'miscpanstars331110_2.txt')
# (0, 'miscpanstars192917_16.txt')
# (0, 'miscpanstars6305_6.txt')
# (0, 'miscpanstars132219_12.txt')
# (0, 'miscpanstars13043_16.txt')
# (0, 'miscpanstars63018_18.txt')
# (0, 'miscpanstars33113_18.txt')
# (0, 'miscpanstars33115_0.txt')
# (0, 'miscpanstars63018_6.txt')
# (0, 'miscpanstars13224_16.txt')
# (0, 'miscpanstars132214_18.txt')
# (0, 'miscpanstars132213_9.txt')
# (0, 'miscpanstars13043_14.txt')
# (0, 'miscpanstars13044_3.txt')
# (0, 'miscpanstars13227_10.txt')
# (0, 'miscpanstars13222_2.txt')
# (0, 'miscpanstars192913_3.txt')
# (0, 'miscpanstars6306_6.txt')
# (0, 'miscpanstars132216_8.txt')
# (0, 'miscpanstars13220_19.txt')
# (0, 'miscastro130412_10.txt')
# (0, 'miscpanstars63019_3.txt')
# (0, 'miscpanstars33118_4.txt')
# (0, 'miscpanstars63014_1.txt')
# (0, 'miscpanstars33112_19.txt')
# (0, 'miscpanstars19299_3.txt')
# (0, 'miscpanstars192911_3.txt')
# (0, 'miscpanstars132218_14.txt')
# (0, 'miscpanstars13046_7.txt')
# (0, 'miscpanstars19297_6.txt')
# (0, 'miscpanstars6304_12.txt')
# (0, 'miscpanstars130413_4.txt')
# (0, 'miscpanstars6308_4.txt')
# (0, 'miscpanstars6308_8.txt')
# (0, 'miscpanstars13048_18.txt')
# (0, 'miscpanstars331119_6.txt')
# (0, 'miscpanstars19292_0.txt')
# (0, 'miscpanstars130415_7.txt')
# (0, 'miscpanstars13049_17.txt')
# (0, 'miscpanstars13223_13.txt')
# (0, 'miscpanstars13227_13.txt')
# (0, 'miscpanstars331114_1.txt')
# (0, 'miscpanstars192911_1.txt')
# (0, 'miscpanstars331119_3.txt')
# (0, 'miscpanstars63014_18.txt')
# (0, 'miscpanstars33111_13.txt')
# (0, 'miscpanstars130419_7.txt')
# (0, 'miscpanstars63011_14.txt')
# (0, 'miscpanstars331114_7.txt')
# (0, 'miscpanstars33116_2.txt')
# (0, 'miscpanstars19290_19.txt')
# (0, 'miscpanstars63018_1.txt')
# (0, 'miscpanstars130417_7.txt')
# (0, 'miscpanstars63014_6.txt')
# (0, 'miscpanstars13045_12.txt')
# (0, 'miscpanstars192919_5.txt')
# (0, 'miscpanstars13222_12.txt')
# (0, 'miscpanstars19298_6.txt')
# (0, 'miscpanstars331116_5.txt')
# (0, 'miscpanstars13220_9.txt')
# (0, 'miscpanstars13049_5.txt')
# (0, 'miscpanstars6300_8.txt')
# (0, 'miscpanstars19290_16.txt')
# (0, 'miscpanstars19293_14.txt')
# (0, 'miscpanstars13229_4.txt')
# (0, 'miscpanstars132212_0.txt')
# (0, 'miscpanstars6302_13.txt')
# (0, 'miscpanstars192915_7.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000368
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5694029 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5702378 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscpanstars132211_10.txt')
# (0, 'miscpanstars132215_17.txt')
# (0, 'miscpanstars132212_15.txt')
# (0, 'miscpanstars33110_0.txt')
# (0, 'miscpanstars19294_4.txt')
# (0, 'miscpanstars132217_7.txt')
# (0, 'miscpanstars331116_10.txt')
# (0, 'miscpanstars13227_1.txt')
# (0, 'miscpanstars192916_14.txt')
# (0, 'miscastro13042_11.txt')
# (0, 'miscpanstars130415_6.txt')
# (0, 'miscpanstars63013_17.txt')
# (0, 'miscpanstars63015_15.txt')
# (0, 'miscpanstars13043_3.txt')
# (0, 'miscpanstars63017_11.txt')
# (0, 'miscpanstars33116_4.txt')
# (0, 'miscpanstars6300_18.txt')
# (0, 'miscpanstars63018_8.txt')
# (0, 'miscpanstars63017_12.txt')
# (0, 'miscastro130412_15.txt')
# (0, 'miscpanstars130416_19.txt')
# (0, 'miscpanstars130414_1.txt')
# (0, 'miscpanstars331119_7.txt')
# (0, 'miscpanstars13040_7.txt')
# (0, 'miscpanstars13040_17.txt')
# (0, 'miscpanstars132218_9.txt')
# (0, 'miscpanstars13221_13.txt')
# (0, 'miscpanstars331110_3.txt')
# (0, 'miscpanstars33118_0.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000368
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5694029 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5712043 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5712043 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000368
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5694029 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00185
#  - Using 5 steps per peak; omega_step = 0.000369
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5673609 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscpanstars13229_7.txt')
# (0, 'miscpanstars13045_16.txt')
# (0, 'miscpanstars19296_6.txt')
# (0, 'miscpanstars331119_12.txt')
# (0, 'miscpanstars331119_4.txt')
# (0, 'miscastro13041_15.txt')
# (0, 'miscpanstars132216_12.txt')
# (0, 'miscpanstars132217_11.txt')
# (0, 'miscpanstars63015_3.txt')
# (0, 'miscpanstars6308_18.txt')
# (0, 'miscpanstars19292_12.txt')
# (0, 'miscpanstars130412_16.txt')
# (0, 'miscpanstars132210_19.txt')
# (0, 'miscpanstars130411_10.txt')
# (0, 'miscpanstars19291_2.txt')
# (0, 'miscpanstars63010_1.txt')
# (0, 'miscpanstars19290_5.txt')
# (0, 'miscpanstars132216_7.txt')
# (0, 'miscpanstars13041_14.txt')
# (0, 'miscpanstars63010_13.txt')
# (0, 'miscpanstars13046_5.txt')
# (0, 'miscpanstars331117_19.txt')
# (0, 'miscpanstars63013_7.txt')
# (0, 'miscpanstars33118_12.txt')
# (0, 'miscpanstars6307_0.txt')
# (0, 'miscpanstars6307_19.txt')
# (0, 'miscpanstars130411_16.txt')
# (0, 'miscpanstars331112_9.txt')
# (0, 'miscpanstars33113_0.txt')
# (0, 'miscpanstars6308_6.txt')
# (0, 'miscpanstars13046_12.txt')
# (0, 'miscpanstars6302_11.txt')
# (0, 'miscpanstars130414_15.txt')
# (0, 'miscpanstars132211_19.txt')
# (0, 'miscpanstars6301_1.txt')
# (0, 'miscastro13043_2.txt')
# (0, 'miscpanstars132214_9.txt')
# (0, 'miscpanstars192918_13.txt')
# (0, 'miscpanstars130417_4.txt')
# (0, 'miscpanstars63012_6.txt')
# (0, 'miscpanstars33118_15.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5702378 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5712043 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscpanstars331117_14.txt')
# (0, 'miscpanstars13048_15.txt')
# (0, 'miscpanstars13049_16.txt')
# (0, 'miscpanstars130417_11.txt')
# (0, 'miscpanstars192912_6.txt')
# (0, 'miscastro13042_16.txt')
# (0, 'miscpanstars13043_10.txt')
# (0, 'miscpanstars130414_0.txt')
# (0, 'miscpanstars33119_3.txt')
# (0, 'miscpanstars192915_5.txt')
# (0, 'miscpanstars6303_6.txt')
# (0, 'miscpanstars13225_2.txt')
# (0, 'miscpanstars13229_0.txt')
# (0, 'miscpanstars13228_19.txt')
# (0, 'miscpanstars132219_4.txt')
# (0, 'miscpanstars13045_13.txt')
# (0, 'miscpanstars13226_4.txt')
# (0, 'miscpanstars6304_0.txt')
# (0, 'miscpanstars192911_9.txt')
# (0, 'miscpanstars132215_14.txt')
# (0, 'miscpanstars63016_9.txt')
# (0, 'miscpanstars63014_16.txt')
# (0, 'miscpanstars130412_19.txt')
# (0, 'miscpanstars19299_14.txt')
# (0, 'miscpanstars192913_16.txt')
# (0, 'miscpanstars63013_16.txt')
# (0, 'miscpanstars6303_15.txt')
# (0, 'miscpanstars132212_8.txt')
# (0, 'miscpanstars19290_14.txt')
# (0, 'miscpanstars6303_13.txt')
# (0, 'miscpanstars331111_1.txt')
# (0, 'miscpanstars13047_8.txt')
# (0, 'miscpanstars33119_15.txt')
# (0, 'miscpanstars63010_8.txt')
# (0, 'miscpanstars33112_4.txt')
# (0, 'miscpanstars6305_3.txt')
# (0, 'miscpanstars130410_5.txt')
# (0, 'miscpanstars6302_7.txt')
# (0, 'miscpanstars132218_12.txt')
# (0, 'miscpanstars130412_0.txt')
# (0, 'miscpanstars331111_0.txt')
# (0, 'miscpanstars33117_12.txt')
# (0, 'miscpanstars19297_18.txt')
# (0, 'miscpanstars33118_3.txt')
# (0, 'miscpanstars6305_8.txt')
# (0, 'miscpanstars33115_10.txt')
# (0, 'miscpanstars130418_18.txt')
# (0, 'miscpanstars130410_3.txt')
# (0, 'miscpanstars33114_8.txt')
# (0, 'miscpanstars130419_14.txt')
# (0, 'miscpanstars19297_1.txt')
# (0, 'miscpanstars132218_8.txt')
# (0, 'miscpanstars192916_1.txt')
# (0, 'miscpanstars192914_3.txt')
# (0, 'miscpanstars19290_10.txt')
# (0, 'miscpanstars6302_8.txt')
# (0, 'miscpanstars13048_4.txt')
# (0, 'miscpanstars192912_3.txt')
# (0, 'miscpanstars6307_9.txt')
# (0, 'miscpanstars331111_5.txt')
# (0, 'miscpanstars13222_17.txt')
# (0, 'miscpanstars33117_2.txt')
# (0, 'miscpanstars132210_6.txt')
# (0, 'miscpanstars130419_1.txt')
# (0, 'miscpanstars192913_8.txt')
# (0, 'miscpanstars331114_11.txt')
# (0, 'miscpanstars192910_1.txt')
# (0, 'miscpanstars331115_19.txt')
# (0, 'miscpanstars13047_2.txt')
# (0, 'miscpanstars33118_14.txt')
# (0, 'miscpanstars19295_16.txt')
# (0, 'miscpanstars33116_11.txt')
# (0, 'miscpanstars130416_18.txt')
# (0, 'miscpanstars331119_1.txt')
# (0, 'miscpanstars19299_4.txt')
# (0, 'miscpanstars33112_15.txt')
# (0, 'miscpanstars331115_8.txt')
# (0, 'miscpanstars331118_11.txt')
# (0, 'miscpanstars13040_9.txt')
# (0, 'miscpanstars19299_11.txt')
# (0, 'miscpanstars331111_11.txt')
# (0, 'miscpanstars192917_11.txt')
# (0, 'miscpanstars13223_17.txt')
# (0, 'miscpanstars6309_4.txt')
# (0, 'miscpanstars33111_17.txt')
# (0, 'miscpanstars63013_19.txt')
# (0, 'miscpanstars13049_13.txt')
# (0, 'miscpanstars331113_15.txt')
# (0, 'miscpanstars13224_2.txt')
# (0, 'miscpanstars331118_14.txt')
# (0, 'miscpanstars13227_11.txt')
# (0, 'miscpanstars132213_7.txt')
# (0, 'miscpanstars13047_16.txt')
# (0, 'miscpanstars331119_9.txt')
# (0, 'miscpanstars63019_0.txt')
# (0, 'miscpanstars331112_1.txt')
# (0, 'miscpanstars132214_8.txt')
# (0, 'miscpanstars33115_19.txt')
# (0, 'miscpanstars13224_19.txt')
# (0, 'miscpanstars331117_11.txt')
# (0, 'miscpanstars63012_15.txt')
# (0, 'miscpanstars192911_17.txt')
# (0, 'miscpanstars63011_4.txt')
# (0, 'miscpanstars130419_18.txt')
# (0, 'miscpanstars6309_15.txt')
# (0, 'miscpanstars130411_6.txt')
# (0, 'miscpanstars13043_6.txt')
# (0, 'miscpanstars19293_18.txt')
# (0, 'miscpanstars6306_7.txt')
# (0, 'miscpanstars13044_8.txt')
# (0, 'miscpanstars132217_0.txt')
# (0, 'miscpanstars192918_4.txt')
# (0, 'miscpanstars192919_8.txt')
# (0, 'miscpanstars132216_9.txt')
# (0, 'miscpanstars33110_4.txt')
# (0, 'miscpanstars33118_13.txt')
# (0, 'miscpanstars63013_8.txt')
# (0, 'miscpanstars132213_17.txt')
# (0, 'miscpanstars331115_6.txt')
# (0, 'miscpanstars331114_6.txt')
# (0, 'miscpanstars192914_19.txt')
# (0, 'miscpanstars130411_2.txt')
# (0, 'miscpanstars63019_1.txt')
# (0, 'miscpanstars33115_17.txt')
# (0, 'miscpanstars192917_6.txt')
# (0, 'miscpanstars192913_9.txt')
# (0, 'miscpanstars19298_18.txt')
# (0, 'miscpanstars13226_8.txt')
# (0, 'miscpanstars132211_3.txt')
# (0, 'miscpanstars13040_18.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5702378 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5702378 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.0019
#  - Using 5 steps per peak; omega_step = 0.00038
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5513958 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5712043 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscpanstars19291_11.txt')
# (0, 'miscpanstars33117_11.txt')
# (0, 'miscpanstars331118_10.txt')
# (0, 'miscpanstars63019_13.txt')
# (0, 'miscpanstars130418_13.txt')
# (0, 'miscpanstars130411_19.txt')
# (0, 'miscpanstars132211_7.txt')
# (0, 'miscpanstars13048_1.txt')
# (0, 'miscpanstars192914_7.txt')
# (0, 'miscpanstars6302_6.txt')
# (0, 'miscpanstars33116_17.txt')
# (0, 'miscpanstars192915_0.txt')
# (0, 'miscpanstars130411_13.txt')
# (0, 'miscpanstars63011_19.txt')
# (0, 'miscastro130411_18.txt')
# (0, 'miscpanstars13229_18.txt')
# (0, 'miscpanstars331117_15.txt')
# (0, 'miscpanstars63013_9.txt')
# (0, 'miscpanstars33119_4.txt')
# (0, 'miscastro13042_4.txt')
# (0, 'miscpanstars130413_7.txt')
# (0, 'miscpanstars192914_11.txt')
# (0, 'miscpanstars130413_18.txt')
# (0, 'miscpanstars19293_11.txt')
# (0, 'miscpanstars19295_3.txt')
# (0, 'miscpanstars63013_4.txt')
# (0, 'miscpanstars192911_15.txt')
# (0, 'miscpanstars6303_3.txt')
# (0, 'miscpanstars6305_1.txt')
# (0, 'miscpanstars33114_0.txt')
# (0, 'miscpanstars132210_17.txt')
# (0, 'miscpanstars331117_4.txt')
# (0, 'miscpanstars63013_5.txt')
# (0, 'miscpanstars63015_1.txt')
# (0, 'miscpanstars13044_13.txt')
# (0, 'miscpanstars132211_8.txt')
# (0, 'miscpanstars331119_19.txt')
# (0, 'miscpanstars63011_7.txt')
# (0, 'miscpanstars63014_13.txt')
# (0, 'miscpanstars192912_4.txt')
# (0, 'miscpanstars6304_15.txt')
# (0, 'miscpanstars192911_18.txt')
# (0, 'miscpanstars13224_5.txt')
# (0, 'miscpanstars130417_13.txt')
# (0, 'miscpanstars192918_11.txt')
# (0, 'miscpanstars19294_11.txt')
# (0, 'miscpanstars13042_16.txt')
# (0, 'miscpanstars130415_2.txt')
# (0, 'miscpanstars33116_7.txt')
# (0, 'miscpanstars132210_3.txt')
# (0, 'miscpanstars13042_17.txt')
# (0, 'miscpanstars33115_18.txt')
# (0, 'miscpanstars331115_10.txt')
# (0, 'miscpanstars132210_15.txt')
# (0, 'miscpanstars19294_13.txt')
# (0, 'miscpanstars132219_3.txt')
# (0, 'miscpanstars6304_10.txt')
# (0, 'miscpanstars19295_11.txt')
# (0, 'miscpanstars130415_14.txt')
# (0, 'miscpanstars33116_5.txt')
# (0, 'miscpanstars63017_3.txt')
# (0, 'miscpanstars6306_18.txt')
# (0, 'miscpanstars130412_6.txt')
# (0, 'miscpanstars331113_8.txt')
# (0, 'miscpanstars130419_4.txt')
# (0, 'miscpanstars130410_15.txt')
# (0, 'miscpanstars13224_0.txt')
# (0, 'miscpanstars13047_0.txt')
# (0, 'miscpanstars132213_15.txt')
# (0, 'miscpanstars6302_18.txt')
# (0, 'miscpanstars130415_4.txt')
# (0, 'miscpanstars33112_8.txt')
# (0, 'miscpanstars33115_16.txt')
# (0, 'miscpanstars331113_6.txt')
# (0, 'miscpanstars6301_8.txt')
# (0, 'miscpanstars13229_8.txt')
# (0, 'miscpanstars13223_7.txt')
# (0, 'miscpanstars130417_17.txt')
# (0, 'miscpanstars19297_15.txt')
# (0, 'miscpanstars13041_12.txt')
# (0, 'miscpanstars130410_1.txt')
# (0, 'miscpanstars6301_6.txt')
# (0, 'miscpanstars33114_4.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000368
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5694029 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5712043 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscpanstars19291_17.txt')
# (0, 'miscpanstars19295_15.txt')
# (0, 'miscpanstars130410_19.txt')
# (0, 'miscpanstars19296_15.txt')
# (0, 'miscpanstars130412_18.txt')
# (0, 'miscpanstars33118_16.txt')
# (0, 'miscpanstars331118_16.txt')
# (0, 'miscpanstars33117_8.txt')
# (0, 'miscpanstars13229_16.txt')
# (0, 'miscpanstars63010_2.txt')
# (0, 'miscpanstars33111_6.txt')
# (0, 'miscpanstars33110_11.txt')
# (0, 'miscpanstars130412_4.txt')
# (0, 'miscpanstars6308_17.txt')
# (0, 'miscpanstars33118_1.txt')
# (0, 'miscpanstars6307_11.txt')
# (0, 'miscpanstars130418_9.txt')
# (0, 'miscpanstars192919_13.txt')
# (0, 'miscastro13041_7.txt')
# (0, 'miscpanstars13225_5.txt')
# (0, 'miscpanstars19290_18.txt')
# (0, 'miscpanstars130413_6.txt')
# (0, 'miscpanstars6307_5.txt')
# (0, 'miscpanstars132218_19.txt')
# (0, 'miscpanstars13046_13.txt')
# (0, 'miscpanstars13222_1.txt')
# (0, 'miscpanstars33113_9.txt')
# (0, 'miscpanstars19298_15.txt')
# (0, 'miscpanstars13221_3.txt')
# (0, 'miscpanstars13046_4.txt')
# (0, 'miscpanstars331112_19.txt')
# (0, 'miscpanstars6309_16.txt')
# (0, 'miscpanstars63012_4.txt')
# (0, 'miscpanstars13220_18.txt')
# (0, 'miscpanstars6305_15.txt')
# (0, 'miscpanstars19295_1.txt')
# (0, 'miscpanstars6308_14.txt')
# (0, 'miscpanstars132217_4.txt')
# (0, 'miscpanstars132213_19.txt')
# (0, 'miscpanstars6303_1.txt')
# (0, 'miscpanstars33113_13.txt')
# (0, 'miscpanstars19295_5.txt')
# (0, 'miscpanstars192915_13.txt')
# (0, 'miscpanstars33111_14.txt')
# (0, 'miscpanstars33113_19.txt')
# (0, 'miscpanstars13227_7.txt')
# (0, 'miscpanstars33117_6.txt')
# (0, 'miscpanstars13043_7.txt')
# (0, 'miscpanstars63017_8.txt')
# (0, 'miscpanstars63017_0.txt')
# (0, 'miscpanstars19299_1.txt')
# (0, 'miscpanstars331119_0.txt')
# (0, 'miscpanstars130417_10.txt')
# (0, 'miscpanstars33113_7.txt')
# (0, 'miscpanstars6308_3.txt')
# (0, 'miscpanstars63017_10.txt')
# (0, 'miscpanstars331113_12.txt')
# (0, 'miscpanstars19291_0.txt')
# (0, 'miscpanstars6307_10.txt')
# (0, 'miscpanstars132217_5.txt')
# (0, 'miscpanstars63016_19.txt')
# (0, 'miscpanstars130414_2.txt')
# (0, 'miscpanstars13221_6.txt')
# (0, 'miscpanstars130414_19.txt')
# (0, 'miscastro13042_9.txt')
# (0, 'miscpanstars6307_14.txt')
# (0, 'miscpanstars130415_13.txt')
# (0, 'miscpanstars331111_18.txt')
# (0, 'miscpanstars13049_18.txt')
# (0, 'miscpanstars19293_15.txt')
# (0, 'miscpanstars130412_9.txt')
# (0, 'miscpanstars132217_2.txt')
# (0, 'miscpanstars132211_18.txt')
# (0, 'miscpanstars33110_19.txt')
# (0, 'miscpanstars33115_3.txt')
# (0, 'miscpanstars19292_19.txt')
# (0, 'miscpanstars192912_16.txt')
# (0, 'miscpanstars13222_9.txt')
# (0, 'miscpanstars19291_4.txt')
# (0, 'miscpanstars192911_13.txt')
# (0, 'miscpanstars192918_15.txt')
# (0, 'miscastro13042_15.txt')
# (0, 'miscpanstars13223_3.txt')
# (0, 'miscpanstars19294_18.txt')
# (0, 'miscpanstars192912_11.txt')
# (0, 'miscpanstars6301_5.txt')
# (0, 'miscastro13041_3.txt')
# (0, 'miscpanstars192917_19.txt')
# (0, 'miscpanstars132216_5.txt')
# (0, 'miscpanstars130417_5.txt')
# (0, 'miscpanstars33117_18.txt')
# (0, 'miscpanstars130419_15.txt')
# (0, 'miscpanstars19297_4.txt')
# (0, 'miscpanstars33116_6.txt')
# (0, 'miscpanstars132213_14.txt')
# (0, 'miscastro13041_10.txt')
# (0, 'miscpanstars192914_17.txt')
# (0, 'miscpanstars192919_14.txt')
# (0, 'miscpanstars33116_0.txt')
# (0, 'miscpanstars6309_8.txt')
# (0, 'miscpanstars13049_9.txt')
# (0, 'miscpanstars130418_19.txt')
# (0, 'miscpanstars6302_5.txt')
# (0, 'miscastro13040_17.txt')
# (0, 'miscpanstars19297_16.txt')
# (0, 'miscpanstars331115_0.txt')
# (0, 'miscpanstars331118_1.txt')
# (0, 'miscpanstars130413_12.txt')
# (0, 'miscpanstars13221_10.txt')
# (0, 'miscpanstars63010_17.txt')
# (0, 'miscpanstars13221_12.txt')
# (0, 'miscpanstars13227_19.txt')
# (0, 'miscpanstars33110_8.txt')
# (0, 'miscpanstars33110_5.txt')
# (0, 'miscpanstars13220_8.txt')
# (0, 'miscpanstars13041_1.txt')
# (0, 'miscpanstars33119_7.txt')
# (0, 'miscpanstars130412_13.txt')
# (0, 'miscpanstars19293_19.txt')
# (0, 'miscpanstars132219_17.txt')
# (0, 'miscpanstars13044_11.txt')
# (0, 'miscpanstars331119_10.txt')
# (0, 'miscpanstars130410_18.txt')
# (0, 'miscpanstars6308_11.txt')
# (0, 'miscpanstars192917_8.txt')
# (0, 'miscpanstars33119_5.txt')
# (0, 'miscpanstars331110_16.txt')
# (0, 'miscpanstars331110_0.txt')
# (0, 'miscpanstars331114_4.txt')
# (0, 'miscpanstars331114_3.txt')
# (0, 'miscpanstars13044_9.txt')
# (0, 'miscpanstars13220_1.txt')
# (0, 'miscpanstars331117_18.txt')
# (0, 'miscpanstars33119_17.txt')
# (0, 'miscpanstars19293_0.txt')
# (0, 'miscpanstars33110_17.txt')
# (0, 'miscpanstars331115_7.txt')
# (0, 'miscpanstars192915_11.txt')
# (0, 'miscpanstars331113_3.txt')
# (0, 'miscpanstars33119_8.txt')
# (0, 'miscpanstars13224_4.txt')
# (0, 'miscpanstars63012_13.txt')
# (0, 'miscpanstars130417_12.txt')
# (0, 'miscpanstars19297_3.txt')
# (0, 'miscpanstars192910_14.txt')
# (0, 'miscpanstars130413_11.txt')
# (0, 'miscpanstars331113_16.txt')
# (0, 'miscpanstars33118_7.txt')
# (0, 'miscpanstars192917_17.txt')
# (0, 'miscpanstars63015_17.txt')
# (0, 'miscpanstars13043_5.txt')
# (0, 'miscpanstars19292_4.txt')
# (0, 'miscastro130411_14.txt')
# (0, 'miscpanstars13049_15.txt')
# (0, 'miscpanstars130416_3.txt')
# (0, 'miscpanstars6301_15.txt')
# (0, 'miscpanstars6304_19.txt')
# (0, 'miscpanstars192915_4.txt')
# (0, 'miscpanstars130418_17.txt')
# (0, 'miscpanstars13040_4.txt')
# (0, 'miscpanstars192910_18.txt')
# (0, 'miscpanstars132216_4.txt')
# (0, 'miscpanstars192911_19.txt')
# (0, 'miscpanstars331110_8.txt')
# (0, 'miscpanstars13225_17.txt')
# (0, 'miscpanstars132214_14.txt')
# (0, 'miscpanstars13046_16.txt')
# (0, 'miscpanstars132210_4.txt')
# (0, 'miscpanstars63012_7.txt')
# (0, 'miscpanstars33112_6.txt')
# (0, 'miscpanstars33115_2.txt')
# (0, 'miscpanstars6307_6.txt')
# (0, 'miscpanstars19298_2.txt')
# (0, 'miscpanstars331118_13.txt')
# (0, 'miscpanstars331116_9.txt')
# (0, 'miscpanstars13046_8.txt')
# (0, 'miscpanstars6307_8.txt')
# (0, 'miscpanstars6308_10.txt')
# (0, 'miscpanstars13045_1.txt')
# (0, 'miscpanstars63016_16.txt')
# (0, 'miscpanstars13047_14.txt')
# (0, 'miscpanstars331118_18.txt')
# (0, 'miscpanstars132217_13.txt')
# (0, 'miscpanstars13047_19.txt')
# (0, 'miscpanstars132219_10.txt')
# (0, 'miscpanstars19291_14.txt')
# (0, 'miscpanstars33110_15.txt')
# (0, 'miscastro13042_7.txt')
# (0, 'miscpanstars13047_9.txt')
# (0, 'miscpanstars19295_17.txt')
# (0, 'miscpanstars13221_9.txt')
# (0, 'miscpanstars132212_18.txt')
# (0, 'miscpanstars63011_9.txt')
# (0, 'miscpanstars33111_11.txt')
# (0, 'miscpanstars33115_15.txt')
# (0, 'miscpanstars132214_17.txt')
# (0, 'miscpanstars192912_7.txt')
# (0, 'miscpanstars13221_18.txt')
# (0, 'miscpanstars192918_1.txt')
# (0, 'miscpanstars192913_2.txt')
# (0, 'miscpanstars331116_6.txt')
# (0, 'miscpanstars13224_13.txt')
# (0, 'miscpanstars19295_8.txt')
# (0, 'miscpanstars33114_10.txt')
# (0, 'miscpanstars33114_9.txt')
# (0, 'miscpanstars63018_11.txt')
# (0, 'miscpanstars13228_16.txt')
# (0, 'miscpanstars63017_4.txt')
# (0, 'miscpanstars331111_16.txt')
# (0, 'miscpanstars6305_16.txt')
# (0, 'miscpanstars13045_4.txt')
# (0, 'miscpanstars13042_9.txt')
# (0, 'miscpanstars331111_4.txt')
# (0, 'miscpanstars19293_9.txt')
# (0, 'miscpanstars6300_1.txt')
# (0, 'miscpanstars19298_9.txt')
# (0, 'miscpanstars33113_8.txt')
# (0, 'miscpanstars13042_15.txt')
# (0, 'miscpanstars192918_6.txt')
# (0, 'miscpanstars13228_11.txt')
# (0, 'miscpanstars130414_14.txt')
# (0, 'miscpanstars331119_17.txt')
# (0, 'miscpanstars6304_3.txt')
# (0, 'miscpanstars19299_8.txt')
# (0, 'miscpanstars192915_9.txt')
# (0, 'miscpanstars19297_7.txt')
# (0, 'miscpanstars6306_17.txt')
# (0, 'miscpanstars6302_9.txt')
# (0, 'miscpanstars6306_9.txt')
# (0, 'miscpanstars13041_2.txt')
# (0, 'miscpanstars130410_9.txt')
# (0, 'miscpanstars13228_4.txt')
# (0, 'miscpanstars13048_12.txt')
# (0, 'miscpanstars33117_17.txt')
# (0, 'miscpanstars6302_14.txt')
# (0, 'miscpanstars13229_10.txt')
# (0, 'miscpanstars130413_10.txt')
# (0, 'miscpanstars192914_13.txt')
# (0, 'miscpanstars19291_3.txt')
# (0, 'miscpanstars13045_14.txt')
# (0, 'miscpanstars132213_0.txt')
# (0, 'miscpanstars6306_3.txt')
# (0, 'miscpanstars33117_0.txt')
# (0, 'miscpanstars192917_2.txt')
# (0, 'miscpanstars13041_16.txt')
# (0, 'miscpanstars331115_4.txt')
# (0, 'miscpanstars331114_17.txt')
# (0, 'miscpanstars130410_6.txt')
# (0, 'miscpanstars6304_1.txt')
# (0, 'miscpanstars33110_14.txt')
# (0, 'miscpanstars6303_10.txt')
# (0, 'miscastro13041_13.txt')
# (0, 'miscpanstars6309_7.txt')
# (0, 'miscastro13040_12.txt')
# (0, 'miscpanstars331112_15.txt')
# (0, 'miscpanstars13042_0.txt')
# (0, 'miscpanstars63014_19.txt')
# (0, 'miscpanstars63011_10.txt')
# (0, 'miscpanstars13222_0.txt')
# (0, 'miscpanstars63012_14.txt')
# (0, 'miscpanstars19294_19.txt')
# (0, 'miscpanstars63015_12.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00185
#  - Using 5 steps per peak; omega_step = 0.000369
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5673609 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00189
#  - Using 5 steps per peak; omega_step = 0.000377
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5550853 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscpanstars13229_13.txt')
# (0, 'miscastro13042_3.txt')
# (0, 'miscpanstars19296_4.txt')
# (0, 'miscpanstars13229_6.txt')
# (0, 'miscpanstars192917_13.txt')
# (0, 'miscpanstars33117_5.txt')
# (0, 'miscpanstars13040_8.txt')
# (0, 'miscpanstars19299_16.txt')
# (0, 'miscpanstars19296_19.txt')
# (0, 'miscpanstars192915_18.txt')
# (0, 'miscpanstars33110_12.txt')
# (0, 'miscpanstars13227_4.txt')
# (0, 'miscpanstars63017_17.txt')
# (0, 'miscpanstars132216_11.txt')
# (0, 'miscpanstars33111_8.txt')
# (0, 'miscpanstars132215_4.txt')
# (0, 'miscpanstars130412_14.txt')
# (0, 'miscpanstars19293_12.txt')
# (0, 'miscpanstars130414_11.txt')
# (0, 'miscpanstars132218_5.txt')
# (0, 'miscpanstars6306_13.txt')
# (0, 'miscpanstars63015_7.txt')
# (0, 'miscpanstars33116_9.txt')
# (0, 'miscpanstars63016_2.txt')
# (0, 'miscpanstars63010_15.txt')
# (0, 'miscpanstars19297_0.txt')
# (0, 'miscpanstars19291_18.txt')
# (0, 'miscpanstars132212_5.txt')
# (0, 'miscpanstars6302_10.txt')
# (0, 'miscpanstars13047_15.txt')
# (0, 'miscpanstars33114_17.txt')
# (0, 'miscpanstars13225_9.txt')
# (0, 'miscpanstars6307_13.txt')
# (0, 'miscpanstars33112_11.txt')
# (0, 'miscpanstars13044_7.txt')
# (0, 'miscpanstars130413_9.txt')
# (0, 'miscpanstars192914_0.txt')
# (0, 'miscpanstars192916_17.txt')
# (0, 'miscpanstars6301_17.txt')
# (0, 'miscpanstars33118_6.txt')
# (0, 'miscpanstars130415_1.txt')
# (0, 'miscpanstars13223_19.txt')
# (0, 'miscpanstars13041_3.txt')
# (0, 'miscpanstars13225_7.txt')
# (0, 'miscpanstars33118_2.txt')
# (0, 'miscpanstars132215_10.txt')
# (0, 'miscpanstars19298_4.txt')
# (0, 'miscpanstars132215_2.txt')
# (0, 'miscpanstars132218_7.txt')
# (0, 'miscpanstars63013_1.txt')
# (0, 'miscpanstars132218_18.txt')
# (0, 'miscpanstars130416_7.txt')
# (0, 'miscpanstars33118_10.txt')
# (0, 'miscpanstars19290_8.txt')
# (0, 'miscpanstars132212_3.txt')
# (0, 'miscpanstars130417_8.txt')
# (0, 'miscpanstars13046_17.txt')
# (0, 'miscpanstars132217_8.txt')
# (0, 'miscpanstars192910_16.txt')
# (0, 'miscpanstars130410_14.txt')
# (0, 'miscpanstars13044_4.txt')
# (0, 'miscpanstars13047_12.txt')
# (0, 'miscpanstars63010_0.txt')
# (0, 'miscpanstars13221_16.txt')
# (0, 'miscpanstars6304_11.txt')
# (0, 'miscpanstars13042_11.txt')
# (0, 'miscpanstars130411_14.txt')
# (0, 'miscastro130412_0.txt')
# (0, 'miscpanstars192918_9.txt')
# (0, 'miscpanstars192910_6.txt')
# (0, 'miscpanstars13044_0.txt')
# (0, 'miscpanstars19294_17.txt')
# (0, 'miscpanstars13042_6.txt')
# (0, 'miscpanstars19299_18.txt')
# (0, 'miscpanstars331111_6.txt')
# (0, 'miscpanstars19298_10.txt')
# (0, 'miscpanstars33118_9.txt')
# (0, 'miscpanstars130411_3.txt')
# (0, 'miscpanstars6305_10.txt')
# (0, 'miscpanstars6301_14.txt')
# (0, 'miscpanstars13048_0.txt')
# (0, 'miscastro13041_17.txt')
# (0, 'miscpanstars132210_14.txt')
# (0, 'miscpanstars63016_15.txt')
# (0, 'miscpanstars13223_12.txt')
# (0, 'miscpanstars33113_17.txt')
# (0, 'miscpanstars13229_15.txt')
# (0, 'miscpanstars192910_7.txt')
# (0, 'miscpanstars33117_1.txt')
# (0, 'miscpanstars6302_4.txt')
# (0, 'miscpanstars132218_13.txt')
# (0, 'miscpanstars19296_9.txt')
# (0, 'miscpanstars33119_6.txt')
# (0, 'miscpanstars192914_2.txt')
# (0, 'miscpanstars192912_9.txt')
# (0, 'miscpanstars6307_3.txt')
# (0, 'miscpanstars132210_0.txt')
# (0, 'miscpanstars192910_15.txt')
# (0, 'miscpanstars132217_19.txt')
# (0, 'miscpanstars130418_0.txt')
# (0, 'miscpanstars13048_11.txt')
# (0, 'miscpanstars13225_10.txt')
# (0, 'miscpanstars130417_18.txt')
# (0, 'miscpanstars33118_11.txt')
# (0, 'miscpanstars19296_7.txt')
# (0, 'miscpanstars331113_10.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00192
#  - Using 5 steps per peak; omega_step = 0.000383
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5461031 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscpanstars13228_14.txt')
# (0, 'miscpanstars331114_8.txt')
# (0, 'miscpanstars6308_7.txt')
# (0, 'miscastro130411_13.txt')
# (0, 'miscpanstars331115_17.txt')
# (0, 'miscpanstars6302_3.txt')
# (0, 'miscpanstars192916_7.txt')
# (0, 'miscpanstars63018_14.txt')
# (0, 'miscpanstars132212_14.txt')
# (0, 'miscpanstars13222_3.txt')
# (0, 'miscpanstars331119_18.txt')
# (0, 'miscpanstars132210_2.txt')
# (0, 'miscpanstars130413_16.txt')
# (0, 'miscpanstars13222_15.txt')
# (0, 'miscpanstars132215_18.txt')
# (0, 'miscpanstars33119_12.txt')
# (0, 'miscpanstars63013_10.txt')
# (0, 'miscpanstars13228_12.txt')
# (0, 'miscpanstars132217_3.txt')
# (0, 'miscpanstars331118_2.txt')
# (0, 'miscpanstars63018_0.txt')
# (0, 'miscpanstars192915_16.txt')
# (0, 'miscpanstars33111_10.txt')
# (0, 'miscpanstars19298_8.txt')
# (0, 'miscpanstars63011_8.txt')
# (0, 'miscpanstars192918_14.txt')
# (0, 'miscpanstars192918_18.txt')
# (0, 'miscpanstars192919_6.txt')
# (0, 'miscpanstars19295_7.txt')
# (0, 'miscpanstars13045_2.txt')
# (0, 'miscpanstars13227_8.txt')
# (0, 'miscpanstars33115_8.txt')
# (0, 'miscpanstars6301_2.txt')
# (0, 'miscpanstars19299_6.txt')
# (0, 'miscpanstars19291_16.txt')
# (0, 'miscpanstars192912_0.txt')
# (0, 'miscpanstars130418_15.txt')
# (0, 'miscpanstars6306_4.txt')
# (0, 'miscpanstars33115_1.txt')
# (0, 'miscpanstars13224_10.txt')
# (0, 'miscpanstars13225_18.txt')
# (0, 'miscpanstars132218_16.txt')
# (0, 'miscpanstars6300_3.txt')
# (0, 'miscpanstars192919_18.txt')
# (0, 'miscpanstars331112_2.txt')
# (0, 'miscpanstars13045_10.txt')
# (0, 'miscpanstars13043_12.txt')
# (0, 'miscpanstars13223_11.txt')
# (0, 'miscpanstars63018_2.txt')
# (0, 'miscpanstars13221_11.txt')
# (0, 'miscpanstars130418_7.txt')
# (0, 'miscpanstars13047_10.txt')
# (0, 'miscpanstars33115_5.txt')
# (0, 'miscpanstars6304_7.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscpanstars132218_2.txt')
# (0, 'miscpanstars33112_10.txt')
# (0, 'miscpanstars132213_3.txt')
# (0, 'miscpanstars13043_15.txt')
# (0, 'miscpanstars13226_9.txt')
# (0, 'miscpanstars13043_8.txt')
# (0, 'miscpanstars132218_15.txt')
# (0, 'miscpanstars13049_7.txt')
# (0, 'miscpanstars6308_2.txt')
# (0, 'miscpanstars6300_6.txt')
# (0, 'miscpanstars19297_2.txt')
# (0, 'miscpanstars13225_1.txt')
# (0, 'miscpanstars19292_10.txt')
# (0, 'miscpanstars192916_3.txt')
# (0, 'miscpanstars33114_1.txt')
# (0, 'miscpanstars331115_12.txt')
# (0, 'miscpanstars192910_8.txt')
# (0, 'miscpanstars331118_4.txt')
# (0, 'miscpanstars13042_12.txt')
# (0, 'miscpanstars6308_12.txt')
# (0, 'miscpanstars6309_14.txt')
# (0, 'miscpanstars19293_4.txt')
# (0, 'miscpanstars130415_15.txt')
# (0, 'miscpanstars132214_1.txt')
# (0, 'miscpanstars13047_1.txt')
# (0, 'miscpanstars63013_0.txt')
# (0, 'miscpanstars192917_9.txt')
# (0, 'miscpanstars6300_15.txt')
# (0, 'miscpanstars33113_3.txt')
# (0, 'miscpanstars63017_15.txt')
# (0, 'miscpanstars19290_3.txt')
# (0, 'miscpanstars132211_11.txt')
# (0, 'miscpanstars63017_9.txt')
# (0, 'miscastro130412_3.txt')
# (0, 'miscpanstars19291_7.txt')
# (0, 'miscpanstars13228_0.txt')
# (0, 'miscpanstars13223_8.txt')
# (0, 'miscpanstars130412_15.txt')
# (0, 'miscpanstars132213_18.txt')
# (0, 'miscpanstars192918_3.txt')
# (0, 'miscpanstars13222_14.txt')
# (0, 'miscpanstars192919_15.txt')
# (0, 'miscpanstars33111_16.txt')
# (0, 'miscpanstars132217_14.txt')
# (0, 'miscpanstars192916_8.txt')
# (0, 'miscpanstars33115_6.txt')
# (0, 'miscpanstars6300_5.txt')
# (0, 'miscpanstars132215_0.txt')
# (0, 'miscpanstars19292_14.txt')
# (0, 'miscpanstars13220_10.txt')
# (0, 'miscpanstars132212_13.txt')
# (0, 'miscpanstars130410_4.txt')
# (0, 'miscpanstars13046_19.txt')
# (0, 'miscpanstars130414_6.txt')
# (0, 'miscpanstars13226_1.txt')
# (0, 'miscpanstars331112_4.txt')
# (0, 'miscpanstars13225_16.txt')
# (0, 'miscpanstars6303_8.txt')
# (0, 'miscpanstars130418_5.txt')
# (0, 'miscpanstars63015_6.txt')
# (0, 'miscpanstars130415_8.txt')
# (0, 'miscpanstars33112_18.txt')
# (0, 'miscpanstars130415_16.txt')
# (0, 'miscpanstars132210_9.txt')
# (0, 'miscpanstars19298_12.txt')
# (0, 'miscpanstars130419_16.txt')
# (0, 'miscpanstars13226_13.txt')
# (0, 'miscpanstars132216_0.txt')
# (0, 'miscpanstars6300_2.txt')
# (0, 'miscastro130411_19.txt')
# (0, 'miscpanstars13224_8.txt')
# (0, 'miscpanstars132212_2.txt')
# (0, 'miscpanstars63019_18.txt')
# (0, 'miscpanstars132214_4.txt')
# (0, 'miscpanstars19299_9.txt')
# (0, 'miscpanstars13220_6.txt')
# (0, 'miscpanstars192910_10.txt')
# (0, 'miscpanstars13229_5.txt')
# (0, 'miscastro13042_1.txt')
# (0, 'miscastro130412_13.txt')
# (0, 'miscpanstars331112_6.txt')
# (0, 'miscpanstars132211_12.txt')
# (0, 'miscpanstars19291_10.txt')
# (0, 'miscpanstars63017_16.txt')
# (0, 'miscpanstars63011_12.txt')
# (0, 'miscpanstars132216_18.txt')
# (0, 'miscastro13041_16.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscpanstars19290_12.txt')
# (0, 'miscpanstars13046_3.txt')
# (0, 'miscpanstars132211_6.txt')
# (0, 'miscpanstars6306_16.txt')
# (0, 'miscpanstars192917_12.txt')
# (0, 'miscastro13040_14.txt')
# (0, 'miscpanstars130413_1.txt')
# (0, 'miscpanstars63015_14.txt')
# (0, 'miscpanstars33110_18.txt')
# (0, 'miscpanstars19298_7.txt')
# (0, 'miscpanstars130410_17.txt')
# (0, 'miscpanstars13048_13.txt')
# (0, 'miscpanstars19292_18.txt')
# (0, 'miscpanstars19296_18.txt')
# (0, 'miscpanstars192916_12.txt')
# (0, 'miscpanstars192918_7.txt')
# (0, 'miscpanstars13040_1.txt')
# (0, 'miscpanstars132214_15.txt')
# (0, 'miscpanstars63010_7.txt')
# (0, 'miscpanstars19297_10.txt')
# (0, 'miscpanstars63011_13.txt')
# (0, 'miscpanstars19295_10.txt')
# (0, 'miscastro130411_12.txt')
# (0, 'miscpanstars63015_19.txt')
# (0, 'miscpanstars130414_16.txt')
# (0, 'miscpanstars13047_5.txt')
# (0, 'miscpanstars13049_14.txt')
# (0, 'miscpanstars6305_14.txt')
# (0, 'miscpanstars331113_17.txt')
# (0, 'miscastro13041_12.txt')
# (0, 'miscpanstars13220_15.txt')
# (0, 'miscpanstars63018_10.txt')
# (0, 'miscpanstars13044_15.txt')
# (0, 'miscpanstars130415_11.txt')
# (0, 'miscpanstars63018_9.txt')
# (0, 'miscpanstars13043_1.txt')
# (0, 'miscpanstars132216_16.txt')
# (0, 'miscpanstars13042_1.txt')
# (0, 'miscpanstars192911_8.txt')
# (0, 'miscpanstars6301_9.txt')
# (0, 'miscpanstars331110_15.txt')
# (0, 'miscpanstars63014_2.txt')
# (0, 'miscpanstars13227_9.txt')
# (0, 'miscpanstars130416_16.txt')
# (0, 'miscpanstars6303_7.txt')
# (0, 'miscpanstars130419_10.txt')
# (0, 'miscastro130411_17.txt')
# (0, 'miscpanstars132215_7.txt')
# (0, 'miscpanstars13226_16.txt')
# (0, 'miscpanstars63015_18.txt')
# (0, 'miscpanstars63013_6.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00185
#  - Using 5 steps per peak; omega_step = 0.000369
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5673609 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscpanstars132219_18.txt')
# (0, 'miscpanstars13045_0.txt')
# (0, 'miscpanstars132214_7.txt')
# (0, 'miscpanstars13043_0.txt')
# (0, 'miscpanstars33114_16.txt')
# (0, 'miscastro130411_15.txt')
# (0, 'miscpanstars63012_12.txt')
# (0, 'miscpanstars13220_4.txt')
# (0, 'miscpanstars130415_3.txt')
# (0, 'miscpanstars132214_19.txt')
# (0, 'miscpanstars19299_15.txt')
# (0, 'miscpanstars331117_12.txt')
# (0, 'miscpanstars130413_0.txt')
# (0, 'miscpanstars192914_8.txt')
# (0, 'miscpanstars13227_14.txt')
# (0, 'miscpanstars13042_14.txt')
# (0, 'miscpanstars192917_1.txt')
# (0, 'miscpanstars13048_14.txt')
# (0, 'miscpanstars130413_14.txt')
# (0, 'miscpanstars13046_11.txt')
# (0, 'miscpanstars33111_2.txt')
# (0, 'miscpanstars331113_9.txt')
# (0, 'miscpanstars19296_2.txt')
# (0, 'miscpanstars13043_4.txt')
# (0, 'miscpanstars63018_13.txt')
# (0, 'miscpanstars192911_10.txt')
# (0, 'miscpanstars132219_11.txt')
# (0, 'miscpanstars33116_13.txt')
# (0, 'miscpanstars192915_14.txt')
# (0, 'miscastro130412_1.txt')
# (0, 'miscastro13042_17.txt')
# (0, 'miscastro13041_18.txt')
# (0, 'miscpanstars192919_4.txt')
# (0, 'miscpanstars33117_14.txt')
# (0, 'miscpanstars132211_0.txt')
# (0, 'miscpanstars13046_9.txt')
# (0, 'miscpanstars19295_14.txt')
# (0, 'miscpanstars19292_15.txt')
# (0, 'miscpanstars33112_12.txt')
# (0, 'miscpanstars6308_15.txt')
# (0, 'miscpanstars132217_15.txt')
# (0, 'miscpanstars19298_5.txt')
# (0, 'miscpanstars13045_7.txt')
# (0, 'miscpanstars13227_15.txt')
# (0, 'miscpanstars6305_2.txt')
# (0, 'miscpanstars6304_4.txt')
# (0, 'miscpanstars130416_14.txt')
# (0, 'miscpanstars63012_1.txt')
# (0, 'miscpanstars331114_16.txt')
# (0, 'miscpanstars130414_3.txt')
# (0, 'miscpanstars6303_4.txt')
# (0, 'miscpanstars13045_15.txt')
# (0, 'miscpanstars19295_13.txt')
# (0, 'miscpanstars13229_3.txt')
# (0, 'miscpanstars331110_7.txt')
# (0, 'miscpanstars13221_17.txt')
# (0, 'miscpanstars192917_5.txt')
# (0, 'miscastro130412_5.txt')
# (0, 'miscpanstars130411_0.txt')
# (0, 'miscpanstars33112_13.txt')
# (0, 'miscpanstars33118_8.txt')
# (0, 'miscpanstars6300_0.txt')
# (0, 'miscpanstars132213_12.txt')
# (0, 'miscpanstars132213_11.txt')
# (0, 'miscpanstars19290_13.txt')
# (0, 'miscpanstars13049_2.txt')
# (0, 'miscpanstars13226_10.txt')
# (0, 'miscpanstars63012_10.txt')
# (0, 'miscpanstars19291_19.txt')
# (0, 'miscpanstars33114_18.txt')
# (0, 'miscpanstars6301_0.txt')
# (0, 'miscpanstars130412_7.txt')
# (0, 'miscpanstars19297_14.txt')
# (0, 'miscpanstars19299_0.txt')
# (0, 'miscpanstars6300_9.txt')
# (0, 'miscpanstars6306_2.txt')
# (0, 'miscpanstars13221_0.txt')
# (0, 'miscpanstars6304_8.txt')
# (0, 'miscpanstars63017_19.txt')
# (0, 'miscpanstars192916_2.txt')
# (0, 'miscpanstars331118_8.txt')
# (0, 'miscpanstars13049_19.txt')
# (0, 'miscpanstars132213_10.txt')
# (0, 'miscpanstars13227_3.txt')
# (0, 'miscpanstars13049_1.txt')
# (0, 'miscpanstars130413_15.txt')
# (0, 'miscpanstars331116_17.txt')
# (0, 'miscpanstars6305_12.txt')
# (0, 'miscpanstars192918_2.txt')
# (0, 'miscpanstars63014_12.txt')
# (0, 'miscpanstars63016_7.txt')
# (0, 'miscpanstars132212_12.txt')
# (0, 'miscpanstars331115_5.txt')
# (0, 'miscpanstars6309_10.txt')
# (0, 'miscpanstars331119_5.txt')
# (0, 'miscpanstars19297_17.txt')
# (0, 'miscpanstars63010_19.txt')
# (0, 'miscpanstars19297_11.txt')
# (0, 'miscpanstars130413_17.txt')
# (0, 'miscpanstars13040_14.txt')
# (0, 'miscpanstars13225_6.txt')
# (0, 'miscpanstars63015_8.txt')
# (0, 'miscpanstars13224_1.txt')
# (0, 'miscpanstars13225_19.txt')
# (0, 'miscpanstars63011_16.txt')
# (0, 'miscpanstars19292_16.txt')
# (0, 'miscpanstars13044_18.txt')
# (0, 'miscpanstars132218_6.txt')
# (0, 'miscpanstars13226_11.txt')
# (0, 'miscpanstars6301_10.txt')
# (0, 'miscpanstars19299_12.txt')
# (0, 'miscpanstars6301_16.txt')
# (0, 'miscastro13040_18.txt')
# (0, 'miscpanstars13042_13.txt')
# (0, 'miscpanstars13041_11.txt')
# (0, 'miscastro13041_1.txt')
# (0, 'miscpanstars192919_7.txt')
# (0, 'miscpanstars331117_2.txt')
# (0, 'miscpanstars192912_12.txt')
# (0, 'miscpanstars331113_18.txt')
# ...
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5702378 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000368
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5687238 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5702378 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000368
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5694029 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5712043 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000368
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5694029 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00182
#  - Using 5 steps per peak; omega_step = 0.000365
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5743624 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 995 steps
# (0, 'miscpanstars13226_0.txt')
# (0, 'miscpanstars63012_17.txt')
# (0, 'miscastro13041_9.txt')
# (0, 'miscpanstars192913_13.txt')
# (0, 'miscpanstars19296_10.txt')
# (0, 'miscpanstars132219_14.txt')
# (0, 'miscpanstars331118_7.txt')
# (0, 'miscpanstars6309_17.txt')
# (0, 'miscpanstars6309_18.txt')
# (0, 'miscpanstars331112_0.txt')
# (0, 'miscpanstars19295_9.txt')
# (0, 'miscpanstars132211_5.txt')
# (0, 'miscpanstars331111_12.txt')
# (0, 'miscpanstars331117_6.txt')
# (0, 'miscpanstars19290_11.txt')
# (0, 'miscpanstars6302_1.txt')
# (0, 'miscpanstars130411_17.txt')
# (0, 'miscpanstars130412_2.txt')
# (0, 'miscpanstars192919_10.txt')
# (0, 'miscpanstars192919_3.txt')
# (0, 'miscpanstars13220_11.txt')
# (0, 'miscpanstars33112_17.txt')
# (0, 'miscpanstars331110_13.txt')
# (0, 'miscpanstars6307_15.txt')
# (0, 'miscpanstars130412_10.txt')
# (0, 'miscpanstars63019_14.txt')
# (0, 'miscpanstars33115_14.txt')
# (0, 'miscpanstars192913_11.txt')
# (0, 'miscpanstars130415_0.txt')
# (0, 'miscpanstars192915_3.txt')
# (0, 'miscpanstars13222_16.txt')
# (0, 'miscpanstars6303_19.txt')
# (0, 'miscpanstars331117_5.txt')
# (0, 'miscpanstars33112_0.txt')
# (0, 'miscpanstars132213_2.txt')
# (0, 'miscpanstars33113_16.txt')
# (0, 'miscpanstars13225_3.txt')
# (0, 'miscpanstars132216_15.txt')
# (0, 'miscpanstars6306_14.txt')
# (0, 'miscpanstars13223_18.txt')
# (0, 'miscpanstars33111_18.txt')
# (0, 'miscpanstars6308_19.txt')
# (0, 'miscpanstars19298_3.txt')
# (0, 'miscpanstars63019_11.txt')
# (0, 'miscpanstars63019_12.txt')
# (0, 'miscastro13043_0.txt')
# (0, 'miscpanstars19290_2.txt')
# (0, 'miscastro13042_14.txt')
# (0, 'miscpanstars6301_18.txt')
# (0, 'miscpanstars13226_15.txt')
# (0, 'miscpanstars130414_10.txt')
# (0, 'miscpanstars331116_12.txt')
# (0, 'miscastro13040_15.txt')
# (0, 'miscpanstars33119_13.txt')
# (0, 'miscpanstars132211_15.txt')
# (0, 'miscpanstars6302_19.txt')
# (0, 'miscpanstars63014_8.txt')
# (0, 'miscpanstars192916_10.txt')
# (0, 'miscpanstars192913_10.txt')
# (0, 'miscpanstars130416_11.txt')
# (0, 'miscpanstars130417_9.txt')
# (0, 'miscpanstars130417_0.txt')
# (0, 'miscpanstars6309_11.txt')
# (0, 'miscpanstars13049_6.txt')
# (0, 'miscpanstars6305_17.txt')
# (0, 'miscastro13042_2.txt')
# (0, 'miscpanstars130418_2.txt')
# (0, 'miscpanstars331115_15.txt')
# (0, 'miscpanstars192916_4.txt')
# (0, 'miscpanstars19294_12.txt')
# (0, 'miscpanstars331110_14.txt')
# (0, 'miscpanstars33114_14.txt')
# (0, 'miscpanstars6309_19.txt')
# (0, 'miscpanstars13222_13.txt')
# (0, 'miscpanstars331119_15.txt')
# (0, 'miscpanstars132211_14.txt')
# (0, 'miscpanstars13047_6.txt')
# (0, 'miscpanstars192910_5.txt')
# (0, 'miscpanstars192919_11.txt')
# (0, 'miscpanstars63018_3.txt')
# (0, 'miscastro13041_2.txt')
# (0, 'miscpanstars13226_7.txt')
# (0, 'miscpanstars19292_13.txt')
# (0, 'miscpanstars13045_18.txt')
# (0, 'miscpanstars13220_7.txt')
# (0, 'miscpanstars331114_9.txt')
# (0, 'miscpanstars33115_9.txt')
# (0, 'miscpanstars6309_2.txt')
# (0, 'miscpanstars132213_13.txt')
# (0, 'miscpanstars130418_4.txt')
# (0, 'miscpanstars13045_8.txt')
# (0, 'miscastro130412_7.txt')
# (0, 'miscpanstars19294_15.txt')
# (0, 'miscpanstars19293_8.txt')
# (0, 'miscpanstars132214_3.txt')
# (0, 'miscpanstars13226_5.txt')
# (0, 'miscpanstars19296_17.txt')
# (0, 'miscpanstars6309_5.txt')
# (0, 'miscpanstars13040_15.txt')
# (0, 'miscpanstars331112_14.txt')
# (0, 'miscpanstars13045_3.txt')
# (0, 'miscpanstars331114_15.txt')
# (0, 'miscpanstars13041_18.txt')
# (0, 'miscpanstars192918_0.txt')
# (0, 'miscpanstars192919_0.txt')
# (0, 'miscastro13042_0.txt')
# (0, 'miscpanstars33117_9.txt')
# (0, 'miscpanstars192910_19.txt')
# (0, 'miscastro130412_4.txt')
# (0, 'miscpanstars13229_11.txt')
# (0, 'miscpanstars331110_10.txt')
# (0, 'miscpanstars63015_5.txt')
# (0, 'miscpanstars132216_3.txt')
# (0, 'miscpanstars33117_10.txt')
# (0, 'miscpanstars331116_19.txt')
# (0, 'miscpanstars192916_19.txt')
# (0, 'miscpanstars192911_5.txt')
# (0, 'miscpanstars13221_7.txt')
# (0, 'miscpanstars192919_9.txt')
# (0, 'miscpanstars19295_19.txt')
# (0, 'miscpanstars33114_11.txt')
# (0, 'miscpanstars132212_19.txt')
# (0, 'miscpanstars63015_10.txt')
# (0, 'miscpanstars19292_3.txt')
# (0, 'miscpanstars331117_17.txt')
# (0, 'miscpanstars132213_6.txt')
# (0, 'miscpanstars13225_12.txt')
# (0, 'miscpanstars132213_1.txt')
# (0, 'miscpanstars33110_16.txt')
# (0, 'miscpanstars130417_2.txt')
# (0, 'miscpanstars6300_16.txt')
# (0, 'miscpanstars6307_18.txt')
# (0, 'miscpanstars33114_7.txt')
# (0, 'miscpanstars19297_9.txt')
# (0, 'miscpanstars192918_17.txt')
# (0, 'miscpanstars13048_10.txt')
# (0, 'miscpanstars13046_6.txt')
# (0, 'miscpanstars331113_19.txt')
# (0, 'miscpanstars63015_13.txt')
# (0, 'miscpanstars6302_15.txt')
# (0, 'miscpanstars130416_10.txt')
# (0, 'miscpanstars331114_10.txt')
# (0, 'miscpanstars63014_7.txt')
# (0, 'miscpanstars132219_2.txt')
# (0, 'miscpanstars13048_3.txt')
# (0, 'miscpanstars132210_12.txt')
# (0, 'miscpanstars130419_19.txt')
# (0, 'miscpanstars130413_19.txt')
# (0, 'miscpanstars192918_8.txt')
# (0, 'miscpanstars13046_14.txt')
# (0, 'miscpanstars63019_4.txt')
# (0, 'miscpanstars331118_19.txt')
# (0, 'miscpanstars6305_5.txt')
# (0, 'miscpanstars130410_10.txt')
# (0, 'miscpanstars132215_1.txt')
# (0, 'miscpanstars132214_16.txt')
# (0, 'miscpanstars13220_17.txt')
# (0, 'miscpanstars130416_6.txt')
# (0, 'miscpanstars132217_18.txt')
# (0, 'miscpanstars63011_1.txt')
# (0, 'miscpanstars132219_16.txt')
# (0, 'miscpanstars132219_1.txt')
# (0, 'miscpanstars132214_6.txt')
# (0, 'miscpanstars33112_1.txt')
# (0, 'miscpanstars13221_19.txt')
# (0, 'miscpanstars6307_17.txt')
# (0, 'miscastro13041_8.txt')
# (0, 'miscpanstars132210_13.txt')
# (0, 'miscpanstars19290_0.txt')
# (0, 'miscpanstars192915_8.txt')
# (0, 'miscpanstars13045_9.txt')
# (0, 'miscpanstars19290_6.txt')
# (0, 'miscpanstars63016_12.txt')
# (0, 'miscpanstars192916_5.txt')
# (0, 'miscpanstars19296_5.txt')
# (0, 'miscpanstars130416_8.txt')
# (0, 'miscastro13040_0.txt')
# (0, 'miscpanstars63014_4.txt')
# (0, 'miscpanstars13049_11.txt')
# (0, 'miscpanstars192913_18.txt')
# (0, 'miscpanstars63019_5.txt')
# (0, 'miscpanstars331115_14.txt')
# (0, 'miscpanstars130410_12.txt')
# (0, 'miscpanstars132210_11.txt')
# (0, 'miscpanstars13046_10.txt')
# (0, 'miscpanstars13227_6.txt')
# (0, 'miscpanstars130411_11.txt')
# (0, 'miscpanstars13228_8.txt')
# (0, 'miscpanstars13228_13.txt')
# (0, 'miscpanstars33119_1.txt')
# (0, 'miscpanstars331114_0.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5702378 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# Finding optimal frequency:
#  - Estimated peak width = 0.00184
#  - Using 5 steps per peak; omega_step = 0.000368
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5687252 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscpanstars132215_16.txt')
# (0, 'miscpanstars331111_10.txt')
# (0, 'miscpanstars130419_6.txt')
# (0, 'miscpanstars19299_5.txt')
# (0, 'miscpanstars13041_15.txt')
# (0, 'miscpanstars331119_8.txt')
# (0, 'miscpanstars331116_13.txt')
# (0, 'miscpanstars6303_12.txt')
# (0, 'miscpanstars63012_8.txt')
# (0, 'miscpanstars33116_8.txt')
# (0, 'miscpanstars331112_12.txt')
# (0, 'miscpanstars6309_9.txt')
# (0, 'miscastro13040_13.txt')
# (0, 'miscpanstars192912_19.txt')
# (0, 'miscpanstars33116_1.txt')
# (0, 'miscpanstars6303_16.txt')
# (0, 'miscpanstars63017_2.txt')
# (0, 'miscpanstars331114_12.txt')
# (0, 'miscpanstars132216_13.txt')
# (0, 'miscpanstars331116_11.txt')
# (0, 'miscpanstars33117_16.txt')
# (0, 'miscastro130412_2.txt')
# (0, 'miscpanstars132218_11.txt')
# (0, 'miscpanstars63011_11.txt')
# (0, 'miscpanstars192912_10.txt')
# (0, 'miscpanstars63010_18.txt')
# (0, 'miscpanstars63013_12.txt')
# (0, 'miscpanstars13043_13.txt')
# (0, 'miscpanstars13226_19.txt')
# (0, 'miscastro13042_19.txt')
# (0, 'miscpanstars13227_0.txt')
# (0, 'miscpanstars33111_4.txt')
# (0, 'miscpanstars132219_6.txt')
# (0, 'miscpanstars63018_12.txt')
# (0, 'miscpanstars6307_1.txt')
# (0, 'miscpanstars19294_7.txt')
# (0, 'miscpanstars331113_11.txt')
# (0, 'miscpanstars192915_6.txt')
# (0, 'miscpanstars63014_17.txt')
# (0, 'miscpanstars6300_13.txt')
# (0, 'miscpanstars19291_1.txt')
# (0, 'miscpanstars130412_1.txt')
# (0, 'miscpanstars331115_2.txt')
# (0, 'miscpanstars192910_11.txt')
# (0, 'miscpanstars130411_1.txt')
# (0, 'miscpanstars331118_12.txt')
# (0, 'miscpanstars63018_19.txt')
# (0, 'miscpanstars63017_5.txt')
# (0, 'miscpanstars33111_12.txt')
# (0, 'miscpanstars19294_16.txt')
# (0, 'miscpanstars63016_5.txt')
# (0, 'miscpanstars6301_3.txt')
# (0, 'miscpanstars33110_9.txt')
# (0, 'miscpanstars19294_14.txt')
# (0, 'miscpanstars19294_2.txt')
# (0, 'miscpanstars331110_19.txt')
# (0, 'miscpanstars132219_0.txt')
# (0, 'miscpanstars6300_12.txt')
# (0, 'miscpanstars63015_9.txt')
# (0, 'miscpanstars130414_12.txt')
# (0, 'miscpanstars6306_8.txt')
# (0, 'miscpanstars331112_13.txt')
# (0, 'miscpanstars13045_11.txt')
# (0, 'miscpanstars63013_18.txt')
# (0, 'miscpanstars13228_17.txt')
# (0, 'miscpanstars13221_8.txt')
# (0, 'miscpanstars13042_19.txt')
# (0, 'miscpanstars19295_4.txt')
# (0, 'miscpanstars13224_17.txt')
# (0, 'miscpanstars13227_16.txt')
# (0, 'miscpanstars63018_17.txt')
# (0, 'miscpanstars13228_5.txt')
# (0, 'miscpanstars63011_17.txt')
# (0, 'miscpanstars63016_1.txt')
# (0, 'miscpanstars63019_15.txt')
# (0, 'miscpanstars331111_3.txt')
# (0, 'miscpanstars6302_0.txt')
# (0, 'miscpanstars132211_4.txt')
# (0, 'miscpanstars19293_7.txt')
# (0, 'miscpanstars331115_3.txt')
# (0, 'miscpanstars6300_7.txt')
# (0, 'miscpanstars33116_16.txt')
# (0, 'miscpanstars132217_1.txt')
# (0, 'miscpanstars132219_7.txt')
# (0, 'miscpanstars6305_13.txt')
# (0, 'miscpanstars63010_11.txt')
# (0, 'miscpanstars130414_8.txt')
# (0, 'miscpanstars130411_7.txt')
# (0, 'miscpanstars13047_3.txt')
# (0, 'miscpanstars19293_6.txt')
# (0, 'miscpanstars19294_10.txt')
# (0, 'miscpanstars331116_14.txt')
# (0, 'miscpanstars13040_12.txt')
# (0, 'miscpanstars6303_2.txt')
# (0, 'miscpanstars192917_10.txt')
# (0, 'miscpanstars13229_19.txt')
# (0, 'miscpanstars130412_17.txt')
# (0, 'miscpanstars33116_18.txt')
# (0, 'miscpanstars192911_2.txt')
# (0, 'miscpanstars331112_5.txt')
# (0, 'miscpanstars19294_5.txt')
# (0, 'miscpanstars192912_5.txt')
# (0, 'miscpanstars19295_0.txt')
# (0, 'miscpanstars331114_14.txt')
# (0, 'miscpanstars13040_5.txt')
# (0, 'miscpanstars19295_18.txt')
# (0, 'miscpanstars13040_13.txt')
# (0, 'miscpanstars13222_6.txt')
# (0, 'miscpanstars63014_3.txt')
# (0, 'miscpanstars331115_1.txt')
# (0, 'miscpanstars130418_16.txt')
# (0, 'miscpanstars130416_4.txt')
# (0, 'miscpanstars130417_15.txt')
# (0, 'miscpanstars13041_4.txt')
# (0, 'miscastro13042_13.txt')
# (0, 'miscpanstars19291_13.txt')
# (0, 'miscpanstars6308_9.txt')
# (0, 'miscpanstars19293_17.txt')
# (0, 'miscpanstars130411_18.txt')
# (0, 'miscpanstars13228_7.txt')
# (0, 'miscpanstars19293_10.txt')
# (0, 'miscpanstars33117_3.txt')
# (0, 'miscpanstars13227_17.txt')
# (0, 'miscpanstars33114_15.txt')
# (0, 'miscpanstars13047_18.txt')
# (0, 'miscpanstars13224_11.txt')
# (0, 'miscpanstars19291_12.txt')
# (0, 'miscpanstars331111_7.txt')
# (0, 'miscpanstars19291_9.txt')
# (0, 'miscpanstars63011_18.txt')
# (0, 'miscastro13041_14.txt')
# (0, 'miscpanstars132218_17.txt')
# (0, 'miscastro13041_5.txt')
# (0, 'miscpanstars6303_9.txt')
# (0, 'miscpanstars19290_1.txt')
# (0, 'miscpanstars192913_4.txt')
# Finding optimal frequency:
#  - Estimated peak width = 0.00183
#  - Using 5 steps per peak; omega_step = 0.000367
#  - User-specified period range:  0.003 to 26
#  - Computing periods at 5712043 steps
# Zooming-in on 5 candidate peaks:
#  - Computing periods at 1000 steps
# (0, 'miscpanstars132219_8.txt')
# (0, 'miscpanstars192914_5.txt')
# (0, 'miscpanstars6300_10.txt')
# (0, 'miscpanstars132213_8.txt')
# (0, 'miscpanstars331115_13.txt')
# (0, 'miscpanstars130411_4.txt')
# (0, 'miscpanstars63017_1.txt')
# (0, 'miscpanstars63010_3.txt')
# (0, 'miscpanstars13220_3.txt')
# (0, 'miscpanstars13221_14.txt')
# (0, 'miscpanstars19297_19.txt')
# (0, 'miscpanstars63010_16.txt')
# (0, 'miscpanstars130411_15.txt')
# (0, 'miscpanstars13049_3.txt')
# (0, 'miscpanstars19298_17.txt')
# (0, 'miscpanstars132210_5.txt')
# (0, 'miscpanstars63019_10.txt')
# (0, 'miscpanstars130416_2.txt')
# (0, 'miscpanstars13043_11.txt')
# (0, 'miscpanstars19298_11.txt')
# (0, 'miscpanstars130414_4.txt')
# (0, 'miscpanstars19295_12.txt')
# (0, 'miscpanstars13229_14.txt')
# (0, 'miscpanstars63013_15.txt')
# (0, 'miscpanstars132218_3.txt')
# (0, 'miscpanstars63019_2.txt')
# (0, 'miscpanstars13228_2.txt')
# (0, 'miscpanstars13040_19.txt')
# (0, 'miscpanstars63011_15.txt')
# (0, 'miscpanstars331117_0.txt')
# (0, 'miscastro13042_5.txt')
# (0, 'miscpanstars192914_12.txt')
# (0, 'miscpanstars13220_16.txt')
# (0, 'miscpanstars6303_11.txt')
# (0, 'miscpanstars192918_12.txt')
# (0, 'miscpanstars33111_5.txt')
# (0, 'miscpanstars192917_0.txt')
# (0, 'miscpanstars6309_6.txt')
# (0, 'miscpanstars6300_14.txt')
# (0, 'miscpanstars192913_19.txt')
# (0, 'miscpanstars6305_18.txt')
# (0, 'miscpanstars6301_12.txt')
# (0, 'miscpanstars13042_8.txt')
# (0, 'miscpanstars132217_12.txt')
# (0, 'miscpanstars6308_16.txt')
# (0, 'miscpanstars331112_16.txt')
# (0, 'miscpanstars63018_4.txt')
# (0, 'miscpanstars13221_5.txt')
# (0, 'miscpanstars33110_13.txt')
# (0, 'miscpanstars192914_15.txt')
# (0, 'miscpanstars33116_15.txt')
# (0, 'miscpanstars63013_3.txt')
# (0, 'miscpanstars130417_1.txt')
# (0, 'miscpanstars6307_4.txt')
# (0, 'miscpanstars19296_16.txt')
# (0, 'miscpanstars192914_9.txt')
# (0, 'miscpanstars33119_14.txt')
# (0, 'miscpanstars19293_5.txt')
# (0, 'miscpanstars132217_17.txt')
# (0, 'miscpanstars6307_2.txt')
# (0, 'miscpanstars63014_14.txt')
# (0, 'miscpanstars6304_6.txt')
# (0, 'miscpanstars331112_11.txt')
# (0, 'miscpanstars63014_11.txt')
# (0, 'miscpanstars33114_12.txt')
# (0, 'miscpanstars63016_8.txt')
# (0, 'miscpanstars192915_19.txt')
# (0, 'miscpanstars13044_17.txt')
# (0, 'miscpanstars13222_18.txt')
# (0, 'miscpanstars13227_5.txt')
# (0, 'miscpanstars33113_15.txt')
# (0, 'miscpanstars13226_12.txt')
# (0, 'miscpanstars13223_10.txt')
# (0, 'miscpanstars6306_15.txt')
# (0, 'miscpanstars192914_10.txt')
# (0, 'miscpanstars192911_16.txt')
# (0, 'miscastro130411_9.txt')
# (0, 'miscpanstars132215_6.txt')
# (0, 'miscpanstars13229_2.txt')
# (0, 'miscpanstars19294_0.txt')
# (0, 'miscpanstars6304_17.txt')
# (0, 'miscpanstars63016_17.txt')
# (0, 'miscpanstars192916_18.txt')
# (0, 'miscpanstars192918_10.txt')
# (0, 'miscpanstars63012_19.txt')
# (0, 'miscpanstars33110_6.txt')
# (0, 'miscpanstars13229_12.txt')
# (0, 'miscpanstars63010_9.txt')
# (0, 'miscpanstars6306_12.txt')
# (0, 'miscpanstars130418_1.txt')

# %%
print(misclist[0][:-3])
# Out:
# miscastro19298_17.

# %%
temporaryFile.py
